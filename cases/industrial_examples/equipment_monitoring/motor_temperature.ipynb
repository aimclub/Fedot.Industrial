# %% [markdown]
# ## Predict permanent magnet synchronous motor (PMSM) rotor temperature with Fedot.Industrial

# %% [markdown]
# The data set comprises several sensor data collected from a permanent magnet synchronous motor (PMSM) deployed on a test bench. All recordings are sampled at 2 Hz. The motor is excited by hand-designed driving cycles denoting a reference motor speed and a reference torque. Currents in d/q-coordinates (columns "i_d" and i_q") and voltages in d/q-coordinates (columns "u_d" and "u_q") are a result of a standard control strategy trying to follow the reference speed and torque. This "sample" of ElectricMotorTemperature dataset was created by first splitting the measurement sessions into groups of 30 consecutive seconds, i.e. 60 timepoints. Then, used the **recorded ambient**, **coolant temperatures**, **d and q components of voltage**, **current** as predictors to form 6- dimensional time series of length 60. The target variable is the **maximum recorded rotor temperature during each respective 30-second time frame**. The resulting dataset has 22148 instances, of which 70% were sampled as training data and the remaining 30% as testing data.
# Link to the dataset - https://www.kaggle.com/datasets/wkirgsn/electric-motor-temperature

# %%
import pandas as pd
from functools import partial

from fedot_ind.api.utils.path_lib import PROJECT_PATH
from fedot.core.pipelines.pipeline_builder import PipelineBuilder
from fedot_ind.tools.loader import DataLoader
from fedot_ind.core.repository.initializer_industrial_models import IndustrialModels
from examples.example_utils import init_input_data, calculate_regression_metric
from golem.core.tuning.sequential import SequentialTuner
from fedot.core.pipelines.tuning.tuner_builder import TunerBuilder
from fedot.core.repository.quality_metrics_repository import RegressionMetricsEnum

# %% [markdown]
# The list of basic fedot industrial models for experiment are shown below. We are using simple linear machine learning pipelines with 3 different feature generators: Statistical, Recurrence, Topological. And for each of them we add PCA transformation with 90 % of explained dispersion.

# %%
model_dict = {
    'regression_with_statistical_features': PipelineBuilder().add_node('quantile_extractor',
                                                                       params={'window_size': 5}).add_node('ridge'),
    'regression_pca_with_statistical_features': PipelineBuilder().add_node('quantile_extractor',
                                                                           params={'window_size': 5}).
    add_node('pca', params={'n_components': 0.9}).add_node('ridge'),
    'regression_with_recurrence_features': PipelineBuilder().add_node('recurrence_extractor',
                                                                           params={'window_size': 20}).add_node('ridge'),
    'regression_pca_with_recurrence_features': PipelineBuilder().add_node('recurrence_extractor',
                                                                           params={'window_size': 20}).
    add_node('pca', params={'n_components': 0.9}).add_node('ridge'),
    'regression_with_topological_features': PipelineBuilder().add_node('topological_extractor',
                                                                           params={'window_size': 20}).
    add_node('pca', params={'n_components': 0.9}).add_node('ridge'),
    'regression_pca_with_topological_features': PipelineBuilder().add_node('topological_extractor',
                                                                           params={'window_size': 20}).
    add_node('pca', params={'n_components': 0.9}).add_node('ridge')
}

dataset_name = 'ElectricMotorTemperature'
data_path = PROJECT_PATH + '/examples/data'
tuning_params = {'task': 'regression',
                 'metric': RegressionMetricsEnum.RMSE,
                 'tuning_timeout':10,
                 'tuning_iterations':30}

# %%
def evaluate_industrial_model(train_data, test_data, task:str = 'regression'):
    metric_dict = {}
    input_data = init_input_data(train_data[0], train_data[1], task=task)
    val_data = init_input_data(test_data[0], test_data[1], task=task)
    with IndustrialModels():
        for model in model_dict.keys():
            print(f'Current_model - {model}')
            pipeline = model_dict[model].build()
            pipeline.fit(input_data)
            features = pipeline.predict(val_data).predict
            metric = calculate_regression_metric(test_target=test_data[1], labels=features)
            metric_dict.update({model: metric})
    return metric_dict

def tuning_industrial_pipelines(pipeline, tuning_params, train_data):
    input_data = init_input_data(train_data[0], train_data[1], task=tuning_params['task'])
    pipeline_tuner = TunerBuilder(input_data.task) \
        .with_tuner(partial(SequentialTuner, inverse_node_order=True)) \
        .with_metric(tuning_params['metric']) \
        .with_timeout(tuning_params['tuning_timeout']) \
        .with_iterations(tuning_params['tuning_iterations']) \
        .build(input_data)

    pipeline = pipeline_tuner.tune(pipeline)
    return pipeline

# %% [markdown]
# Now we must download the dataset. It could be done by using `DataReader` class that implemented as attribute of `FedotIndustrial` class. This class firstly tries to read the data from local project folder `data_path` and then if it is not possible, it downloads the data from the UCR/UEA archive. The data will be saved in the `data` folder.

# %%
_, train_data, test_data = DataLoader(dataset_name=dataset_name).read_train_test_files(
            dataset_name=dataset_name,
            data_path=data_path)
# Out:
# 2023-10-12 15:37:31,970 - Reading data from D:\WORK\Repo\Industiral\IndustrialTS/examples/data/ElectricMotorTemperature

# %%
input_data = init_input_data(train_data[0], train_data[1], task=tuning_params['task'])
val_data = init_input_data(test_data[0], test_data[1], task=tuning_params['task'])

# %% [markdown]
# Lets check our data.

# %%
input_data.features.shape
# Out:
# (15503, 6, 60)

# %% [markdown]
# Lets visualise our predictors.

# %%
from matplotlib import pyplot as plt
pd.DataFrame(input_data.features[1, 0, :]).plot(title='q-Voltage')
pd.DataFrame(input_data.features[1, 1, :]).plot(title='d-Voltage')
pd.DataFrame(input_data.features[1, 2, :]).plot(title='q-Current')
pd.DataFrame(input_data.features[1, 3, :]).plot(title='d-Current')
pd.DataFrame(input_data.features[1, 4, :]).plot(title='Ambient temperature')
pd.DataFrame(input_data.features[1, 5, :]).plot(title='Coolant tempperature')
plt.show()

# %% [markdown]
# Next steps are quite straightforward. We need to fit the model and then predict the values for the test data just like for any other model in sklearn.
#
# At the `fit` stage FedotIndustrial will transform initial time series data into features dataframe and will train regression model.

# %%
metric_dict = evaluate_industrial_model(train_data,test_data)
# Out:
# Current_model - regression_with_statistical_features
# Current_model - regression_pca_with_statistical_features
# Current_model - regression_with_reccurence_features
# Current_model - regression_pca_with_reccurence_features
# Current_model - regression_with_topological_features
# Current_model - regression_pca_with_topological_features

# %% [markdown]
# At the end of the experiment we can obtain the desired metric values using `calculate_regression_metric` method. Now there are five available metrics for classification task:
# - `explained_variance_score`
# - `max_error`
# - `mean_absolute_error`
# - `mean_squared_error`
# - `d2_absolute_error_score`.
# - `median_absolute_error`
# - `r2_score`

# %%
df_baseline = pd.concat([x for x in metric_dict.values()],axis=1)
df_baseline.columns = list(metric_dict.keys())
df_baseline = df_baseline.T
df_baseline
# Out:
#                                           r2_score:  mean_squared_error:  \
# regression_with_statistical_features       0.693983           112.378612
# regression_pca_with_statistical_features  -0.000023           367.238547
# regression_with_reccurence_features        0.039149           352.853347
# regression_pca_with_reccurence_features    0.031494           355.664772
# regression_with_topological_features       0.197249           294.794248
# regression_pca_with_topological_features   0.197249           294.794248
#
#                                           root_mean_squared_error:  \
# regression_with_statistical_features                     10.600878
# regression_pca_with_statistical_features                 19.163469
# regression_with_reccurence_features                      18.784391
# regression_pca_with_reccurence_features                  18.859077
# regression_with_topological_features                     17.169573
# regression_pca_with_topological_features                 17.169573
#
#                                           mean_absolute_error  \
# regression_with_statistical_features                 7.958599
# regression_pca_with_statistical_features            16.032184
# regression_with_reccurence_features                 15.529970
# regression_pca_with_reccurence_features             15.617512
# regression_with_topological_features                13.730141
# regression_pca_with_topological_features            13.730141
#
#                                           median_absolute_error  \
# regression_with_statistical_features                   6.222807
# regression_pca_with_statistical_features              14.537957
# regression_with_reccurence_features                   13.787723
# regression_pca_with_reccurence_features               13.971815
# regression_with_topological_features                  11.850148
# regression_pca_with_topological_features              11.850148
#
#                                           explained_variance_score  max_error  \
# regression_with_statistical_features                      0.694109  62.702171
# regression_pca_with_statistical_features                 -0.000023  54.768756
# regression_with_reccurence_features                       0.039151  56.811154
# regression_pca_with_reccurence_features                   0.031502  56.561991
# regression_with_topological_features                      0.197265  73.042515
# regression_pca_with_topological_features                  0.197265  73.042515
#
#                                           d2_absolute_error_score
# regression_with_statistical_features                     0.502193
# regression_pca_with_statistical_features                -0.002806
# regression_with_reccurence_features                      0.028607
# regression_pca_with_reccurence_features                  0.023132
# regression_with_topological_features                     0.141186
# regression_pca_with_topological_features                 0.141186

# %%
best_baseline = df_baseline.sort_values('root_mean_squared_error:')['root_mean_squared_error:'].iloc[0]

# %% [markdown]
# ## Could it be done better? Tuning approach

# %%
metric_dict = {}

# %%
with IndustrialModels():
    for model in model_dict.keys():
        print(f'Current_model - {model}')
        pipeline = model_dict[model].build()
        tuned_pipeline = tuning_industrial_pipelines(pipeline,tuning_params,train_data)
        tuned_pipeline.fit(input_data)
        features = tuned_pipeline.predict(val_data).predict
        metric = calculate_regression_metric(test_target=test_data[1], labels=features)
        metric = metric.T
        metric.columns = metric.columns.values
        metric['model_params'] = metric['model_params'] = str({node:node.parameters for node in tuned_pipeline.graph_description['nodes']})
        metric_dict.update({model: metric})
# Out:
# Current_model - regression_with_statistical_features
# 2023-10-09 17:54:44,392 - DataSourceSplitter - Stratificated splitting of data is disabled.
# 2023-10-09 17:54:44,393 - DataSourceSplitter - Hold out validation is applied.
# 2023-10-09 17:54:44,403 - SequentialTuner - Hyperparameters optimization start: estimation of metric for initial graph
# 2023-10-09 17:58:41,281 - SequentialTuner - Initial graph: {'depth': 2, 'length': 2, 'nodes': [ridge, quantile_extractor]}
# ridge - {}
# quantile_extractor - {'window_size': 5}
# Initial metric: [10.669]
#   0%|          | 0/15 [00:00<?, ?trial/s, best loss=?]2023-10-09 17:58:41,293 - build_posterior_wrapper took 0.001025 seconds
# 2023-10-09 17:58:41,294 - TPE using 0 trials
#   7%|▋         | 1/15 [03:17<46:06, 197.61s/trial, best loss: 10.589717340713692]
#   0%|          | 0/15 [00:00<?, ?trial/s, best loss=?]2023-10-09 18:01:58,908 - build_posterior_wrapper took 0.000998 seconds
# 2023-10-09 18:01:58,908 - TPE using 0 trials
#   7%|▋         | 1/15 [03:14<45:24, 194.60s/trial, best loss: 10.58538311588605]
# 2023-10-09 18:05:13,513 - SequentialTuner - Hyperparameters optimization finished
# 2023-10-09 18:08:28,699 - SequentialTuner - Return tuned graph due to the fact that obtained metric 10.585 equal or better than initial (+ 0.05% deviation) 10.664
# 2023-10-09 18:08:28,700 - SequentialTuner - Final graph: {'depth': 2, 'length': 2, 'nodes': [ridge, quantile_extractor]}
# ridge - {'alpha': 1.23024974982525}
# quantile_extractor - {'window_size': 30, 'stride': 5}
# 2023-10-09 18:08:28,701 - SequentialTuner - Final metric: 10.585
# Current_model - regression_pca_with_statistical_features
# 2023-10-09 18:13:06,659 - DataSourceSplitter - Stratificated splitting of data is disabled.
# 2023-10-09 18:13:06,659 - DataSourceSplitter - Hold out validation is applied.
# 2023-10-09 18:13:06,669 - SequentialTuner - Hyperparameters optimization start: estimation of metric for initial graph
# 2023-10-09 18:16:53,970 - SequentialTuner - Initial graph: {'depth': 3, 'length': 3, 'nodes': [ridge, pca, quantile_extractor]}
# ridge - {}
# pca - {'svd_solver': 'full', 'n_components': 0.9}
# quantile_extractor - {'window_size': 5}
# Initial metric: [19.282]
#   0%|          | 0/10 [00:00<?, ?trial/s, best loss=?]2023-10-09 18:16:53,985 - build_posterior_wrapper took 0.000974 seconds
# 2023-10-09 18:16:53,985 - TPE using 0 trials
#  10%|█         | 1/10 [04:02<36:18, 242.09s/trial, best loss: 19.282334039476396]
#   0%|          | 0/10 [00:00<?, ?trial/s, best loss=?]2023-10-09 18:20:56,078 - build_posterior_wrapper took 0.000000 seconds
# 2023-10-09 18:20:56,079 - TPE using 0 trials
#  10%|█         | 1/10 [03:57<35:41, 237.95s/trial, best loss: 19.282373457266235]
#   0%|          | 0/10 [00:00<?, ?trial/s, best loss=?]2023-10-09 18:24:54,029 - build_posterior_wrapper took 0.000000 seconds
# 2023-10-09 18:24:54,030 - TPE using 0 trials
#  10%|█         | 1/10 [04:04<36:37, 244.14s/trial, best loss: 19.282373457266235]
# 2023-10-09 18:28:58,169 - SequentialTuner - Hyperparameters optimization finished
# 2023-10-09 18:32:53,242 - SequentialTuner - Return init graph due to the fact that obtained metric 19.282 worse than initial (+ 0.05% deviation) 19.273
# 2023-10-09 18:32:53,243 - SequentialTuner - Final graph: {'depth': 3, 'length': 3, 'nodes': [ridge, pca, quantile_extractor]}
# ridge - {}
# pca - {'svd_solver': 'full', 'n_components': 0.9}
# quantile_extractor - {'window_size': 5}
# 2023-10-09 18:32:53,244 - SequentialTuner - Final metric: 19.282
# Current_model - regression_with_reccurence_features
# 2023-10-09 18:38:35,411 - DataSourceSplitter - Stratificated splitting of data is disabled.
# 2023-10-09 18:38:35,412 - DataSourceSplitter - Hold out validation is applied.
# 2023-10-09 18:38:35,421 - SequentialTuner - Hyperparameters optimization start: estimation of metric for initial graph
# 2023-10-09 18:38:49,894 - SequentialTuner - Initial graph: {'depth': 2, 'length': 2, 'nodes': [ridge, recurrence_extractor]}
# ridge - {}
# recurrence_extractor - {'window_size': 20}
# Initial metric: [18.929]
#   0%|          | 0/15 [00:00<?, ?trial/s, best loss=?]2023-10-09 18:38:49,900 - build_posterior_wrapper took 0.002976 seconds
# 2023-10-09 18:38:49,901 - TPE using 0 trials
#   7%|▋         | 1/15 [00:13<03:04, 13.15s/trial, best loss: 18.884636754692817]2023-10-09 18:39:03,051 - build_posterior_wrapper took 0.000970 seconds
# 2023-10-09 18:39:03,051 - TPE using 1/1 trials with best loss 18.884637
#  13%|█▎        | 2/15 [00:26<02:50, 13.14s/trial, best loss: 18.884636754692817]2023-10-09 18:39:16,178 - build_posterior_wrapper took 0.002002 seconds
# 2023-10-09 18:39:16,178 - TPE using 2/2 trials with best loss 18.884637
#  20%|██        | 3/15 [00:39<02:37, 13.16s/trial, best loss: 18.884636754692817]2023-10-09 18:39:29,360 - build_posterior_wrapper took 0.000991 seconds
# 2023-10-09 18:39:29,361 - TPE using 3/3 trials with best loss 18.884637
#  27%|██▋       | 4/15 [00:52<02:24, 13.17s/trial, best loss: 18.884636754692817]2023-10-09 18:39:42,561 - build_posterior_wrapper took 0.002121 seconds
# 2023-10-09 18:39:42,562 - TPE using 4/4 trials with best loss 18.884637
#  33%|███▎      | 5/15 [01:02<02:01, 12.12s/trial, best loss: 18.884636754692817]2023-10-09 18:39:52,822 - build_posterior_wrapper took 0.000998 seconds
# 2023-10-09 18:39:52,822 - TPE using 5/5 trials with best loss 18.884637
#  40%|████      | 6/15 [01:08<01:28,  9.81s/trial, best loss: 18.884636754692817]2023-10-09 18:39:58,139 - build_posterior_wrapper took 0.003020 seconds
# 2023-10-09 18:39:58,140 - TPE using 6/6 trials with best loss 18.884637
#  47%|████▋     | 7/15 [01:21<01:27, 10.91s/trial, best loss: 18.884636754692817]2023-10-09 18:40:11,304 - build_posterior_wrapper took 0.001025 seconds
# 2023-10-09 18:40:11,304 - TPE using 7/7 trials with best loss 18.884637
#  53%|█████▎    | 8/15 [01:34<01:21, 11.60s/trial, best loss: 18.884636754692817]2023-10-09 18:40:24,380 - build_posterior_wrapper took 0.000997 seconds
# 2023-10-09 18:40:24,381 - TPE using 8/8 trials with best loss 18.884637
#  60%|██████    | 9/15 [01:48<01:13, 12.23s/trial, best loss: 18.884636754692817]2023-10-09 18:40:38,006 - build_posterior_wrapper took 0.000990 seconds
# 2023-10-09 18:40:38,007 - TPE using 9/9 trials with best loss 18.884637
#  67%|██████▋   | 10/15 [02:01<01:02, 12.52s/trial, best loss: 18.884636754692817]2023-10-09 18:40:51,187 - build_posterior_wrapper took 0.000997 seconds
# 2023-10-09 18:40:51,188 - TPE using 10/10 trials with best loss 18.884637
#  73%|███████▎  | 11/15 [02:14<00:50, 12.70s/trial, best loss: 18.884636754692817]2023-10-09 18:41:04,274 - build_posterior_wrapper took 0.000999 seconds
# 2023-10-09 18:41:04,275 - TPE using 11/11 trials with best loss 18.884637
#  80%|████████  | 12/15 [02:24<00:35, 11.80s/trial, best loss: 18.884636754692817]2023-10-09 18:41:14,014 - build_posterior_wrapper took 0.001982 seconds
# 2023-10-09 18:41:14,014 - TPE using 12/12 trials with best loss 18.884637
#  87%|████████▋ | 13/15 [02:37<00:24, 12.12s/trial, best loss: 18.884636754692817]
#   0%|          | 0/15 [00:00<?, ?trial/s, best loss=?]2023-10-09 18:41:27,437 - build_posterior_wrapper took 0.000000 seconds
# 2023-10-09 18:41:27,438 - TPE using 0 trials
#   7%|▋         | 1/15 [00:13<03:11, 13.65s/trial, best loss: 18.88180707010456]2023-10-09 18:41:41,093 - build_posterior_wrapper took 0.000000 seconds
# 2023-10-09 18:41:41,093 - TPE using 1/1 trials with best loss 18.881807
#  13%|█▎        | 2/15 [00:27<02:55, 13.49s/trial, best loss: 18.88180707010456]2023-10-09 18:41:54,476 - build_posterior_wrapper took 0.001032 seconds
# 2023-10-09 18:41:54,476 - TPE using 2/2 trials with best loss 18.881807
#  20%|██        | 3/15 [00:40<02:41, 13.42s/trial, best loss: 18.88180707010456]2023-10-09 18:42:07,807 - build_posterior_wrapper took 0.000000 seconds
# 2023-10-09 18:42:07,808 - TPE using 3/3 trials with best loss 18.881807
#  27%|██▋       | 4/15 [00:53<02:27, 13.42s/trial, best loss: 18.88180707010456]2023-10-09 18:42:21,216 - build_posterior_wrapper took 0.000993 seconds
# 2023-10-09 18:42:21,216 - TPE using 4/4 trials with best loss 18.881807
#  33%|███▎      | 5/15 [01:07<02:14, 13.49s/trial, best loss: 18.88180707010456]2023-10-09 18:42:34,850 - build_posterior_wrapper took 0.000000 seconds
# 2023-10-09 18:42:34,850 - TPE using 5/5 trials with best loss 18.881807
#  40%|████      | 6/15 [01:20<02:01, 13.45s/trial, best loss: 18.88180707010456]2023-10-09 18:42:48,228 - build_posterior_wrapper took 0.000000 seconds
# 2023-10-09 18:42:48,228 - TPE using 6/6 trials with best loss 18.881807
#  47%|████▋     | 7/15 [01:34<01:47, 13.39s/trial, best loss: 18.88180707010456]2023-10-09 18:43:01,473 - build_posterior_wrapper took 0.000000 seconds
# 2023-10-09 18:43:01,474 - TPE using 7/7 trials with best loss 18.881807
#  53%|█████▎    | 8/15 [01:47<01:33, 13.38s/trial, best loss: 18.88180707010456]2023-10-09 18:43:14,846 - build_posterior_wrapper took 0.000000 seconds
# 2023-10-09 18:43:14,847 - TPE using 8/8 trials with best loss 18.881807
#  60%|██████    | 9/15 [02:00<01:20, 13.42s/trial, best loss: 18.88180707010456]2023-10-09 18:43:28,344 - build_posterior_wrapper took 0.000000 seconds
# 2023-10-09 18:43:28,345 - TPE using 9/9 trials with best loss 18.881807
#  67%|██████▋   | 10/15 [02:14<01:06, 13.38s/trial, best loss: 18.88180707010456]2023-10-09 18:43:41,629 - build_posterior_wrapper took 0.000000 seconds
# 2023-10-09 18:43:41,630 - TPE using 10/10 trials with best loss 18.881807
#  73%|███████▎  | 11/15 [02:27<00:52, 13.22s/trial, best loss: 18.881484136947126]2023-10-09 18:43:54,489 - build_posterior_wrapper took 0.000000 seconds
# 2023-10-09 18:43:54,490 - TPE using 11/11 trials with best loss 18.881484
#  80%|████████  | 12/15 [02:39<00:39, 13.33s/trial, best loss: 18.881484136947126]
# 2023-10-09 18:44:07,346 - SequentialTuner - Hyperparameters optimization finished
# 2023-10-09 18:44:20,114 - SequentialTuner - Return tuned graph due to the fact that obtained metric 18.881 equal or better than initial (+ 0.05% deviation) 18.919
# 2023-10-09 18:44:20,115 - SequentialTuner - Final graph: {'depth': 2, 'length': 2, 'nodes': [ridge, recurrence_extractor]}
# ridge - {'alpha': 0.07955461886043966}
# recurrence_extractor - {'window_size': 35, 'stride': 7}
# 2023-10-09 18:44:20,115 - SequentialTuner - Final metric: 18.881
# Current_model - regression_pca_with_reccurence_features
# 2023-10-09 18:44:39,123 - DataSourceSplitter - Stratificated splitting of data is disabled.
# 2023-10-09 18:44:39,124 - DataSourceSplitter - Hold out validation is applied.
# 2023-10-09 18:44:39,134 - SequentialTuner - Hyperparameters optimization start: estimation of metric for initial graph
# 2023-10-09 18:44:53,582 - SequentialTuner - Initial graph: {'depth': 3, 'length': 3, 'nodes': [ridge, pca, recurrence_extractor]}
# ridge - {}
# pca - {'svd_solver': 'full', 'n_components': 0.9}
# recurrence_extractor - {'window_size': 20}
# Initial metric: [19.031]
#   0%|          | 0/10 [00:00<?, ?trial/s, best loss=?]2023-10-09 18:44:53,586 - build_posterior_wrapper took 0.001039 seconds
# 2023-10-09 18:44:53,587 - TPE using 0 trials
#  10%|█         | 1/10 [00:22<03:23, 22.58s/trial, best loss: 19.00331733725217]2023-10-09 18:45:16,165 - build_posterior_wrapper took 0.001000 seconds
# 2023-10-09 18:45:16,166 - TPE using 1/1 trials with best loss 19.003317
#  20%|██        | 2/10 [00:32<02:01, 15.16s/trial, best loss: 19.00331733725217]2023-10-09 18:45:26,128 - build_posterior_wrapper took 0.000996 seconds
# 2023-10-09 18:45:26,129 - TPE using 2/2 trials with best loss 19.003317
#  30%|███       | 3/10 [00:38<01:16, 10.91s/trial, best loss: 19.00331733725217]2023-10-09 18:45:31,974 - build_posterior_wrapper took 0.001027 seconds
# 2023-10-09 18:45:31,975 - TPE using 3/3 trials with best loss 19.003317
#  40%|████      | 4/10 [00:52<01:12, 12.08s/trial, best loss: 19.00331733725217]2023-10-09 18:45:45,862 - build_posterior_wrapper took 0.001120 seconds
# 2023-10-09 18:45:45,863 - TPE using 4/4 trials with best loss 19.003317
#  50%|█████     | 5/10 [00:59<00:51, 10.32s/trial, best loss: 19.00331733725217]2023-10-09 18:45:53,066 - build_posterior_wrapper took 0.000998 seconds
# 2023-10-09 18:45:53,066 - TPE using 5/5 trials with best loss 19.003317
#  60%|██████    | 6/10 [01:09<00:41, 10.39s/trial, best loss: 19.00331733725217]2023-10-09 18:46:03,582 - build_posterior_wrapper took 0.001000 seconds
# 2023-10-09 18:46:03,582 - TPE using 6/6 trials with best loss 19.003317
#  70%|███████   | 7/10 [01:17<00:28,  9.50s/trial, best loss: 19.00331733725217]2023-10-09 18:46:11,247 - build_posterior_wrapper took 0.000997 seconds
# 2023-10-09 18:46:11,247 - TPE using 7/7 trials with best loss 19.003317
#  80%|████████  | 8/10 [01:28<00:20, 10.04s/trial, best loss: 19.00331733725217]2023-10-09 18:46:22,440 - build_posterior_wrapper took 0.000997 seconds
# 2023-10-09 18:46:22,441 - TPE using 8/8 trials with best loss 19.003317
#  90%|█████████ | 9/10 [01:42<00:11, 11.42s/trial, best loss: 19.00331733725217]
#   0%|          | 0/10 [00:00<?, ?trial/s, best loss=?]2023-10-09 18:46:36,347 - build_posterior_wrapper took 0.000000 seconds
# 2023-10-09 18:46:36,348 - TPE using 0 trials
#  10%|█         | 1/10 [00:22<03:24, 22.76s/trial, best loss: 19.00331733725217]2023-10-09 18:46:59,103 - build_posterior_wrapper took 0.000000 seconds
# 2023-10-09 18:46:59,104 - TPE using 1/1 trials with best loss 19.003317
#  20%|██        | 2/10 [00:45<03:02, 22.85s/trial, best loss: 19.00331733725217]2023-10-09 18:47:22,013 - build_posterior_wrapper took 0.000000 seconds
# 2023-10-09 18:47:22,014 - TPE using 2/2 trials with best loss 19.003317
#  30%|███       | 3/10 [01:07<02:37, 22.53s/trial, best loss: 19.00331733725217]2023-10-09 18:47:44,171 - build_posterior_wrapper took 0.000000 seconds
# 2023-10-09 18:47:44,172 - TPE using 3/3 trials with best loss 19.003317
#  40%|████      | 4/10 [01:30<02:16, 22.72s/trial, best loss: 19.00331733725217]2023-10-09 18:48:07,183 - build_posterior_wrapper took 0.000000 seconds
# 2023-10-09 18:48:07,184 - TPE using 4/4 trials with best loss 19.003317
#  50%|█████     | 5/10 [01:53<01:53, 22.67s/trial, best loss: 19.00331733725217]
#   0%|          | 0/10 [00:00<?, ?trial/s, best loss=?]2023-10-09 18:48:29,694 - build_posterior_wrapper took 0.000998 seconds
# 2023-10-09 18:48:29,694 - TPE using 0 trials
#  10%|█         | 1/10 [00:22<03:20, 22.33s/trial, best loss: 19.003317330491875]2023-10-09 18:48:52,021 - build_posterior_wrapper took 0.000962 seconds
# 2023-10-09 18:48:52,021 - TPE using 1/1 trials with best loss 19.003317
#  20%|██        | 2/10 [00:44<02:59, 22.45s/trial, best loss: 19.003317330491875]2023-10-09 18:49:14,556 - build_posterior_wrapper took 0.000000 seconds
# 2023-10-09 18:49:14,557 - TPE using 2/2 trials with best loss 19.003317
#  30%|███       | 3/10 [01:07<02:38, 22.60s/trial, best loss: 19.003317323119475]2023-10-09 18:49:37,339 - build_posterior_wrapper took 0.000000 seconds
# 2023-10-09 18:49:37,340 - TPE using 3/3 trials with best loss 19.003317
#  40%|████      | 4/10 [01:30<02:15, 22.66s/trial, best loss: 19.003317295311273]2023-10-09 18:50:00,099 - build_posterior_wrapper took 0.000000 seconds
# 2023-10-09 18:50:00,100 - TPE using 4/4 trials with best loss 19.003317
#  50%|█████     | 5/10 [01:52<01:52, 22.53s/trial, best loss: 19.003317283398687]
# 2023-10-09 18:50:22,350 - SequentialTuner - Hyperparameters optimization finished
# 2023-10-09 18:50:45,148 - SequentialTuner - Return tuned graph due to the fact that obtained metric 19.003 equal or better than initial (+ 0.05% deviation) 19.022
# 2023-10-09 18:50:45,148 - SequentialTuner - Final graph: {'depth': 3, 'length': 3, 'nodes': [ridge, pca, recurrence_extractor]}
# ridge - {'alpha': 9.982927425974628}
# pca - {'svd_solver': 'full', 'n_components': 0.8818281309956932}
# recurrence_extractor - {'window_size': 30, 'stride': 5}
# 2023-10-09 18:50:45,149 - SequentialTuner - Final metric: 19.003
# Current_model - regression_with_topological_features
# 2023-10-09 18:51:17,868 - DataSourceSplitter - Stratificated splitting of data is disabled.
# 2023-10-09 18:51:17,869 - DataSourceSplitter - Hold out validation is applied.
# 2023-10-09 18:51:17,879 - SequentialTuner - Hyperparameters optimization start: estimation of metric for initial graph
# 2023-10-09 18:56:41,165 - SequentialTuner - Initial graph: {'depth': 3, 'length': 3, 'nodes': [ridge, pca, topological_extractor]}
# ridge - {}
# pca - {'svd_solver': 'full', 'n_components': 0.9}
# topological_extractor - {'window_size': 20}
# Initial metric: [17.256]
#   0%|          | 0/10 [00:00<?, ?trial/s, best loss=?]2023-10-09 18:56:41,169 - build_posterior_wrapper took 0.000988 seconds
# 2023-10-09 18:56:41,170 - TPE using 0 trials
#  10%|█         | 1/10 [05:29<49:26, 329.57s/trial, best loss: 17.256087584218864]
#   0%|          | 0/10 [00:00<?, ?trial/s, best loss=?]2023-10-09 19:02:10,738 - build_posterior_wrapper took 0.000000 seconds
# 2023-10-09 19:02:10,739 - TPE using 0 trials
#  10%|█         | 1/10 [05:30<49:32, 330.26s/trial, best loss: 18.160241159265333]
#   0%|          | 0/10 [00:00<?, ?trial/s, best loss=?]2023-10-09 19:07:40,996 - build_posterior_wrapper took 0.000000 seconds
# 2023-10-09 19:07:40,997 - TPE using 0 trials
#  10%|█         | 1/10 [05:12<46:55, 312.84s/trial, best loss: 18.160241159441227]
# 2023-10-09 19:12:53,839 - SequentialTuner - Hyperparameters optimization finished
# 2023-10-09 19:18:01,174 - SequentialTuner - Return init graph due to the fact that obtained metric 18.160 worse than initial (+ 0.05% deviation) 17.247
# 2023-10-09 19:18:01,175 - SequentialTuner - Final graph: {'depth': 3, 'length': 3, 'nodes': [ridge, pca, topological_extractor]}
# ridge - {}
# pca - {'svd_solver': 'full', 'n_components': 0.9}
# topological_extractor - {'window_size': 20}
# 2023-10-09 19:18:01,175 - SequentialTuner - Final metric: 17.256
# Current_model - regression_pca_with_topological_features
# 2023-10-09 19:25:20,507 - DataSourceSplitter - Stratificated splitting of data is disabled.
# 2023-10-09 19:25:20,508 - DataSourceSplitter - Hold out validation is applied.
# 2023-10-09 19:25:20,518 - SequentialTuner - Hyperparameters optimization start: estimation of metric for initial graph
# 2023-10-09 19:30:25,738 - SequentialTuner - Initial graph: {'depth': 3, 'length': 3, 'nodes': [ridge, pca, topological_extractor]}
# ridge - {}
# pca - {'svd_solver': 'full', 'n_components': 0.9}
# topological_extractor - {'window_size': 20}
# Initial metric: [17.256]
#   0%|          | 0/10 [00:00<?, ?trial/s, best loss=?]2023-10-09 19:30:25,744 - build_posterior_wrapper took 0.000000 seconds
# 2023-10-09 19:30:25,745 - TPE using 0 trials
#  10%|█         | 1/10 [05:02<45:23, 302.61s/trial, best loss: 16.617816515755134]
#   0%|          | 0/10 [00:00<?, ?trial/s, best loss=?]2023-10-09 19:35:28,354 - build_posterior_wrapper took 0.000000 seconds
# 2023-10-09 19:35:28,355 - TPE using 0 trials
#  10%|█         | 1/10 [05:02<45:26, 302.98s/trial, best loss: 16.80194729334438]
#   0%|          | 0/10 [00:00<?, ?trial/s, best loss=?]2023-10-09 19:40:31,339 - build_posterior_wrapper took 0.000000 seconds
# 2023-10-09 19:40:31,340 - TPE using 0 trials
#  10%|█         | 1/10 [05:02<45:22, 302.54s/trial, best loss: 16.80194728681247]
# 2023-10-09 19:45:33,876 - SequentialTuner - Hyperparameters optimization finished
# 2023-10-09 19:50:38,980 - SequentialTuner - Return tuned graph due to the fact that obtained metric 16.802 equal or better than initial (+ 0.05% deviation) 17.247
# 2023-10-09 19:50:38,980 - SequentialTuner - Final graph: {'depth': 3, 'length': 3, 'nodes': [ridge, pca, topological_extractor]}
# ridge - {'alpha': 6.152967852376552}
# pca - {'svd_solver': 'full', 'n_components': 0.7180519191475635}
# topological_extractor - {'window_size': 10, 'stride': 8}
# 2023-10-09 19:50:38,981 - SequentialTuner - Final metric: 16.802

# %%
df_tuned = pd.concat([x for x in metric_dict.values()],axis=0).T
df_tuned.columns = list(metric_dict.keys())
df_tuned.T.sort_values('root_mean_squared_error:')
# Out:
#                                          r2_score: mean_squared_error:  \
# regression_with_statistical_features      0.667481          122.110994
# regression_pca_with_topological_features  0.251683          274.804607
# regression_with_topological_features      0.197249          294.794248
# regression_with_reccurence_features       0.040916          352.204624
# regression_pca_with_reccurence_features   0.034086          354.712881
# regression_pca_with_statistical_features -0.000023          367.238547
#
#                                          root_mean_squared_error:  \
# regression_with_statistical_features                    11.050384
# regression_pca_with_topological_features                16.577232
# regression_with_topological_features                    17.169573
# regression_with_reccurence_features                     18.767115
# regression_pca_with_reccurence_features                 18.833823
# regression_pca_with_statistical_features                19.163469
#
#                                          mean_absolute_error  \
# regression_with_statistical_features                7.982502
# regression_pca_with_topological_features           13.168824
# regression_with_topological_features               13.730141
# regression_with_reccurence_features                15.521417
# regression_pca_with_reccurence_features            15.584308
# regression_pca_with_statistical_features           16.032184
#
#                                          median_absolute_error  \
# regression_with_statistical_features                  6.290121
# regression_pca_with_topological_features             11.066498
# regression_with_topological_features                 11.850148
# regression_with_reccurence_features                  13.759967
# regression_pca_with_reccurence_features              13.914453
# regression_pca_with_statistical_features             14.537957
#
#                                          explained_variance_score   max_error  \
# regression_with_statistical_features                     0.667519  281.285995
# regression_pca_with_topological_features                 0.251698   79.404936
# regression_with_topological_features                     0.197265   73.042515
# regression_with_reccurence_features                      0.040927   56.877107
# regression_pca_with_reccurence_features                  0.034093   56.681468
# regression_pca_with_statistical_features                -0.000023   54.768756
#
#                                          d2_absolute_error_score  \
# regression_with_statistical_features                    0.500698
# regression_pca_with_topological_features                0.176296
# regression_with_topological_features                    0.141186
# regression_with_reccurence_features                     0.029142
# regression_pca_with_reccurence_features                 0.025209
# regression_pca_with_statistical_features               -0.002806
#
#                                                                                model_params
# regression_with_statistical_features      {ridge: {'alpha': 1.23024974982525}, quantile_...
# regression_pca_with_topological_features  {ridge: {'alpha': 6.152967852376552}, pca: {'s...
# regression_with_topological_features      {ridge: {}, pca: {'svd_solver': 'full', 'n_com...
# regression_with_reccurence_features       {ridge: {'alpha': 0.07955461886043966}, recurr...
# regression_pca_with_reccurence_features   {ridge: {'alpha': 9.982927425974628}, pca: {'s...
# regression_pca_with_statistical_features  {ridge: {}, pca: {'svd_solver': 'full', 'n_com...

# %%
df_tuned.T.sort_values('root_mean_squared_error:')['model_params'].iloc[0]
# Out:
# "{ridge: {'alpha': 1.23024974982525}, quantile_extractor: {'window_size': 30, 'stride': 5}}"

# %%
best_tuned = df_tuned.T.sort_values('root_mean_squared_error:')['root_mean_squared_error:'].iloc[0]

# %% [markdown]
# ## Even better? AutoML approach

# %%
metric_dict = {}
runs = 5
for run in range(runs):
    with IndustrialModels():
        auto_ml = PipelineBuilder().add_node('quantile_extractor',
                                              params={'window_size': 5}).add_node('fedot_regr',
                                                                             params={'timeout': 10,'logging_level':30}).build()
        auto_ml.fit(input_data)
        features = auto_ml.predict(val_data).predict
        metric = calculate_regression_metric(test_target=test_data[1], labels=features)
        metric = metric.T
        metric.columns = metric.columns.values
        metric['model_params'] = metric['model_params'] = str({node:node.parameters for node in auto_ml.graph_description['nodes']})
        metric_dict.update({f'run_number - {run}':metric})
# Out:
# 2023-10-12 15:29:10,559 - AssumptionsHandler - Memory consumption for fitting of the initial pipeline in main session: current 297.5 MiB, max: 702.1 MiB
# 2023-10-12 15:29:10,569 - ApiComposer - Initial pipeline was fitted in 1565.6 sec.
# 2023-10-12 15:29:10,570 - AssumptionsHandler - Preset was changed to fast_train due to fit time estimation for initial model.
# 2023-10-12 15:29:10,576 - ApiComposer - AutoML configured. Parameters tuning: False. Time limit: 10 min. Set of candidate models: ['rfr', 'ridge', 'scaling', 'normalization', 'pca', 'catboostreg', 'xgbreg', 'svr', 'dtreg', 'treg', 'knnreg', 'fast_ica', 'kernel_pca', 'isolation_forest_reg', 'rfe_lin_reg', 'rfe_non_lin_reg'].
# 2023-10-12 15:29:10,578 - ApiComposer - Timeout is too small for composing and is skipped because fit_time is 1565.623006 sec.
# 2023-10-12 15:29:11,043 - ApiComposer - Model generation finished
# 2023-10-12 15:29:11,089 - FEDOT logger - Already fitted initial pipeline is used
# 2023-10-12 15:29:11,092 - FEDOT logger - Final pipeline: {'depth': 2, 'length': 2, 'nodes': [rfr, scaling]}
# rfr - {'n_jobs': 8}
# scaling - {}
# 2023-10-12 15:29:11,092 - MemoryAnalytics - Memory consumption for finish in main session: current 297.6 MiB, max: 702.1 MiB

# %%
df_automl = pd.concat([x for x in metric_dict.values()],axis=0).T
df_automl.columns = list(metric_dict.keys())
df_automl = df_automl.T
df_automl.sort_values('root_mean_squared_error:')

# %% [markdown]
# ## Compare with State of Art (SOTA) models

# %%
df = pd.read_csv(data_path+'/ts_regression_sota_results.csv',sep=';')

# %%
df = df[df['ds/type'] == dataset_name].iloc[:,:25]
df.index = df['algorithm']
df = df.drop(['algorithm','ds/type'], axis=1)
df = df.replace(',','.', regex=True).astype(float)
df['Fedot_Industrial_baseline'] = best_baseline
df['Fedot_Industrial_tuned'] = best_tuned
df['Fedot_Industrial_AutoML'] = 0
df['Fedot_Industrial_AutoML'].iloc[0] = df_automl['root_mean_squared_error:'].min()
df['Fedot_Industrial_AutoML'].iloc[1] = df_automl['root_mean_squared_error:'].max()
df['Fedot_Industrial_AutoML'].iloc[2] = df_automl['root_mean_squared_error:'].mean()
df = df.T

# %%
df.sort_values('min')
# Out:
# algorithm                       min       max   average
# FreshPRINCE_RMSE           1.020426  2.101253  1.490442
# DrCIF_RMSE                 1.046399  2.201153  1.594442
# Fedot_Industrial_AutoML    1.049258  1.349887  1.158612
# RotF_RMSE                  1.097089  2.088333  1.559385
# TSF_RMSE                   1.172730  2.181236  1.684828
# RandF_RMSE                 1.182821  2.446314  1.708196
# XGBoost_RMSE               1.272832  2.511297  1.716903
# Fedot_Industrial_tuned     1.282551  1.282551  1.282551
# RIST_RMSE                  1.301506  1.887153  1.501047
# RDST_RMSE                  1.382981  2.200364  1.772813
# MultiROCKET_RMSE           1.454406  2.137563  1.773578
# SingleInception_RMSE       1.490343  2.633115  2.149368
# Fedot_Industrial_baseline  1.538009  1.538009  1.538009
# InceptionT_RMSE            1.542210  2.574168  2.030315
# 5NN-DTW_RMSE               1.593567  2.502464  2.055256
# CNN_RMSE                   1.602674  2.674200  2.150854
# FPCR-Bs_RMSE               1.607024  2.512605  2.097964
# ResNet_RMSE                1.610736  2.404590  1.938074
# FCN_RMSE                   1.636335  2.559661  2.069046
# FPCR_RMSE                  1.637966  2.523426  2.052389
# Grid-SVR_RMSE              1.699988  2.800419  2.203537
# Ridge_RMSE                 1.713667  2.904762  2.363609
# ROCKET_RMSE                1.856612  2.870444  2.275254
# 5NN-ED_RMSE                1.905470  2.554152  2.251424
# 1NN-ED_RMSE                2.129638  3.281798  2.822595
# 1NN-DTW_RMSE               2.211915  3.408802  2.742105

# %%
df.sort_values('max')
# Out:
# algorithm                       min       max   average
# Fedot_Industrial_tuned     1.282551  1.282551  1.282551
# Fedot_Industrial_AutoML    1.049258  1.349887  1.158612
# Fedot_Industrial_baseline  1.538009  1.538009  1.538009
# RIST_RMSE                  1.301506  1.887153  1.501047
# RotF_RMSE                  1.097089  2.088333  1.559385
# FreshPRINCE_RMSE           1.020426  2.101253  1.490442
# MultiROCKET_RMSE           1.454406  2.137563  1.773578
# TSF_RMSE                   1.172730  2.181236  1.684828
# RDST_RMSE                  1.382981  2.200364  1.772813
# DrCIF_RMSE                 1.046399  2.201153  1.594442
# ResNet_RMSE                1.610736  2.404590  1.938074
# RandF_RMSE                 1.182821  2.446314  1.708196
# 5NN-DTW_RMSE               1.593567  2.502464  2.055256
# XGBoost_RMSE               1.272832  2.511297  1.716903
# FPCR-Bs_RMSE               1.607024  2.512605  2.097964
# FPCR_RMSE                  1.637966  2.523426  2.052389
# 5NN-ED_RMSE                1.905470  2.554152  2.251424
# FCN_RMSE                   1.636335  2.559661  2.069046
# InceptionT_RMSE            1.542210  2.574168  2.030315
# SingleInception_RMSE       1.490343  2.633115  2.149368
# CNN_RMSE                   1.602674  2.674200  2.150854
# Grid-SVR_RMSE              1.699988  2.800419  2.203537
# ROCKET_RMSE                1.856612  2.870444  2.275254
# Ridge_RMSE                 1.713667  2.904762  2.363609
# 1NN-ED_RMSE                2.129638  3.281798  2.822595
# 1NN-DTW_RMSE               2.211915  3.408802  2.742105

# %%
df.sort_values('average')
# Out:
# algorithm                       min       max   average
# Fedot_Industrial_AutoML    1.049258  1.349887  1.158612
# Fedot_Industrial_tuned     1.282551  1.282551  1.282551
# FreshPRINCE_RMSE           1.020426  2.101253  1.490442
# RIST_RMSE                  1.301506  1.887153  1.501047
# Fedot_Industrial_baseline  1.538009  1.538009  1.538009
# RotF_RMSE                  1.097089  2.088333  1.559385
# DrCIF_RMSE                 1.046399  2.201153  1.594442
# TSF_RMSE                   1.172730  2.181236  1.684828
# RandF_RMSE                 1.182821  2.446314  1.708196
# XGBoost_RMSE               1.272832  2.511297  1.716903
# RDST_RMSE                  1.382981  2.200364  1.772813
# MultiROCKET_RMSE           1.454406  2.137563  1.773578
# ResNet_RMSE                1.610736  2.404590  1.938074
# InceptionT_RMSE            1.542210  2.574168  2.030315
# FPCR_RMSE                  1.637966  2.523426  2.052389
# 5NN-DTW_RMSE               1.593567  2.502464  2.055256
# FCN_RMSE                   1.636335  2.559661  2.069046
# FPCR-Bs_RMSE               1.607024  2.512605  2.097964
# SingleInception_RMSE       1.490343  2.633115  2.149368
# CNN_RMSE                   1.602674  2.674200  2.150854
# Grid-SVR_RMSE              1.699988  2.800419  2.203537
# 5NN-ED_RMSE                1.905470  2.554152  2.251424
# ROCKET_RMSE                1.856612  2.870444  2.275254
# Ridge_RMSE                 1.713667  2.904762  2.363609
# 1NN-DTW_RMSE               2.211915  3.408802  2.742105
# 1NN-ED_RMSE                2.129638  3.281798  2.822595
