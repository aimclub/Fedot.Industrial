# %% [markdown]
# # Explainability Methods

# %% [markdown]
# Machine learning models, especially those dealing with time series data, often operate as complex **black boxes**, making it challenging to interpret their decisions. Explainability methods play a crucial role in demystifying these models and enhancing their trustworthiness.
#
# In this notebook, we'll explore key explainability techniques, implemented in out framework, including SHAP, and Time Series Points Perturbation Analysis.

# %% [markdown]
# Before we start with explainability methods, let's train two models: a simple statistical model and a complex one with several preprocessing nodes:

# %%
from fedot.core.pipelines.pipeline_builder import PipelineBuilder
from fedot_ind.core.optimizer.IndustrialEvoOptimizer import IndustrialEvoOptimizer
from fedot_ind.api.main import FedotIndustrial as FI
from fedot_ind.tools.explain.explain import PointExplainer

ml_task = 'classification'
fourier_model = PipelineBuilder().add_node('quantile_extractor').add_node('rf')
eigen_model = PipelineBuilder().add_node('eigen_basis').add_node('quantile_extractor').add_node('rf')
topo_model = PipelineBuilder().add_node('topological_extractor').add_node('rf')
available_operations = {'stat_basis': fourier_model,
                         'eigen_basis':eigen_model,
                         'topo_basis':topo_model}
model_dict = {}
for model_name, model_impl in available_operations.items():
    experiment_setup = {'problem': ml_task,
                        'metric': 'accuracy',
                        'timeout': 5,
                        'num_of_generations': 5,
                        'pop_size': 10,
                        'logging_level': 40,
                        'available_operations':model_impl,
                        'n_jobs': 4,
                        'industrial_preprocessing': True,
                        'initial_assumption': None,
                        'max_pipeline_fit_time': 5,
                        'with_tuning': False,
                        'early_stopping_iterations': 5,
                        'early_stopping_timeout': 10,
                        'optimizer': IndustrialEvoOptimizer}
    automl_model = FI(**experiment_setup)
    model_dict.update({model_name:automl_model})

# %% [markdown]
# ## Synthetic data

# %%
from fedot_ind.tools.synthetic.ts_datasets_generator import TimeSeriesDatasetsGenerator
import matplotlib.pyplot as plt
import numpy as np


generator = TimeSeriesDatasetsGenerator(num_samples=14,
                                        max_ts_len=50,
                                        binary=True)
train_data, test_data = generator.generate_data()
X_test, y_test = test_data
X_train, y_train = train_data

class_1 = np.unique(y_train)[0]
class_2 = np.unique(y_train)[1]
class_1_idx = np.where(y_train == class_1)[0]
class_2_idx = np.where(y_train == class_2)[0]
fig, axs = plt.subplots(2, 1, figsize=(10, 5))
axs[0].plot(X_train.iloc[class_1_idx, :].T)
axs[0].set_title(f'Class {class_1}')
axs[1].plot(X_train.iloc[class_2_idx, :].T)
axs[1].set_title(f'Class {class_2}')
plt.show()

# %%
stat_model = model_dict['stat_basis']
stat_model.fit(input_data=train_data)
stat_labels = stat_model.predict(predict_data=test_data)
stat_probs = stat_model.predict_proba(predict_data=test_data)
# Out:
# 100%|██████████| 14/14 [00:00<00:00, 1403.72it/s]
# 100%|██████████| 14/14 [00:00<00:00, 1079.87it/s]
# 100%|██████████| 14/14 [00:00<00:00, 1754.78it/s]

# %%
metric_df = stat_model.get_metrics(y_test,stat_labels)
metric_df
# Out:
#              0
# accuracy:  1.0
# f1         1.0
# roc_auc:   1.0

# %%
distance = 'euclidean'
explainer = PointExplainer(stat_model, X_test, y_test)
explainer.explain(n_samples=5, window=10, method=distance)
explainer.visual(threshold=0, name='Custom'+'_'+distance)
# Out:
# 100%|██████████| 10/10 [00:00<00:00, 10160.62it/s]
# Processing points:   0%|          | 0/10 [00:00<?, ?point/s]
# 100%|██████████| 10/10 [00:00<00:00, 10027.02it/s]
#
# 100%|██████████| 10/10 [00:00<00:00, 4954.29it/s]
#
# 100%|██████████| 10/10 [00:00<00:00, 10019.84it/s]
#
# 100%|██████████| 10/10 [00:00<00:00, 5019.51it/s]
# Processing points:  40%|████      | 4/10 [00:00<00:00, 32.08point/s]
# 100%|██████████| 10/10 [00:00<00:00, 10275.12it/s]
#
# 100%|██████████| 10/10 [00:00<00:00, 10024.63it/s]
#
# 100%|██████████| 10/10 [00:00<00:00, 10012.66it/s]
#
# 100%|██████████| 10/10 [00:00<00:00, 9733.82it/s]
# Processing points:  80%|████████  | 8/10 [00:00<00:00, 32.22point/s]
# 100%|██████████| 10/10 [00:00<?, ?it/s][A
#
# 100%|██████████| 10/10 [00:00<00:00, 10024.63it/s]
# Processing points: 100%|██████████| 10/10 [00:00<00:00, 32.02point/s]

# %%
eigen_model = model_dict['eigen_basis']
eigen_model.fit(input_data=train_data)
eigen_labels = eigen_model.predict(predict_data=test_data)
eigen_probs = eigen_model.predict_proba(predict_data=test_data)
# Out:
# 2024-01-19 18:28:46,686 - Initialising Industrial Repository
# SVD estimation: 100%|██████████| 14/14 [00:00<00:00, 1278.70it/s]
# 100%|██████████| 14/14 [00:00<00:00, 1002.67it/s]
# 100%|██████████| 14/14 [00:00<00:00, 1003.23it/s]
# 100%|██████████| 14/14 [00:00<00:00, 936.42it/s]

# %%
metric_df = eigen_model.get_metrics(y_test,eigen_labels)
metric_df
# Out:
#              0
# accuracy:  1.0
# f1         1.0
# roc_auc:   1.0

# %%
topo_model = model_dict['topo_basis']
topo_model.fit(input_data=train_data)
topo_labels = topo_model.predict(predict_data=test_data)
topo_probs = topo_model.predict_proba(predict_data=test_data)
# Out:
# 2024-01-19 18:28:13,877 - Initialising Industrial Repository
# 100%|██████████| 14/14 [00:00<00:00, 101.72it/s]
# 100%|██████████| 14/14 [00:00<00:00, 104.68it/s]
# 100%|██████████| 14/14 [00:00<00:00, 111.41it/s]

# %%
metric_df = topo_model.get_metrics(y_test,topo_labels)
metric_df
# Out:
#                   0
# accuracy:  0.357143
# f1         0.307692
# roc_auc:   0.366667

# %% [markdown]
# ## Real data

# %%
from fedot_ind.tools.loader import DataLoader
dataset = 'Beef'
train_data_beef, test_data_beef = DataLoader(dataset).load_data()

# %%
available_operations = {'stat_basis': fourier_model,
                         'eigen_basis':eigen_model,
                         'topo_basis':topo_model}
model_dict = {}
for model_name, model_impl in available_operations.items():
    experiment_setup = {'problem': ml_task,
                        'metric': 'accuracy',
                        'timeout': 5,
                        'num_of_generations': 5,
                        'pop_size': 10,
                        'logging_level': 40,
                        'available_operations':model_impl,
                        'n_jobs': 4,
                        'industrial_preprocessing': True,
                        'initial_assumption': None,
                        'max_pipeline_fit_time': 5,
                        'with_tuning': False,
                        'early_stopping_iterations': 5,
                        'early_stopping_timeout': 10,
                        'optimizer': IndustrialEvoOptimizer}
    automl_model = FI(**experiment_setup)
    model_dict.update({model_name:automl_model})
stat_model_beef = model_dict['stat_basis']
stat_model_beef.fit(train_data_beef)
stat_labels_beef = stat_model_beef.predict(test_data_beef)
stat_probs_beef = stat_model_beef.predict_proba(train_data_beef)
# Out:
# 100%|██████████| 30/30 [00:00<00:00, 578.77it/s]
# 100%|██████████| 30/30 [00:00<00:00, 589.78it/s]
# 100%|██████████| 30/30 [00:00<00:00, 589.81it/s]

# %%
metric_df_stat_beef = stat_model_beef.get_metrics(train_data_beef[1],stat_labels_beef,stat_probs_beef)
metric_df_stat_beef
# Out:
#                   0
# accuracy:  0.533333
# f1         0.515556
# roc_auc:   1.000000

# %%
distance = 'euclidean'
explainer = PointExplainer(stat_model_beef,test_data_beef[0],test_data_beef[1])
explainer.explain(n_samples=5, window=10, method=distance)
explainer.visual(threshold=0, name='Beef')
# Out:
# 100%|██████████| 25/25 [00:00<00:00, 451.60it/s]
# Processing points:   0%|          | 0/10 [00:00<?, ?point/s]
# 100%|██████████| 25/25 [00:00<00:00, 456.02it/s]
# Processing points:  10%|█         | 1/10 [00:00<00:01,  7.11point/s]
# 100%|██████████| 25/25 [00:00<00:00, 482.05it/s]
# Processing points:  20%|██        | 2/10 [00:00<00:01,  7.14point/s]
# 100%|██████████| 25/25 [00:00<00:00, 501.33it/s]
# Processing points:  30%|███       | 3/10 [00:00<00:00,  7.20point/s]
# 100%|██████████| 25/25 [00:00<00:00, 410.98it/s]
# Processing points:  40%|████      | 4/10 [00:00<00:00,  6.88point/s]
# 100%|██████████| 25/25 [00:00<00:00, 501.33it/s]
# Processing points:  50%|█████     | 5/10 [00:00<00:00,  6.96point/s]
# 100%|██████████| 25/25 [00:00<00:00, 464.20it/s]
# Processing points:  60%|██████    | 6/10 [00:00<00:00,  7.01point/s]
# 100%|██████████| 25/25 [00:00<00:00, 482.06it/s]
# Processing points:  70%|███████   | 7/10 [00:01<00:00,  6.75point/s]
# 100%|██████████| 25/25 [00:00<00:00, 482.06it/s]
# Processing points:  80%|████████  | 8/10 [00:01<00:00,  6.89point/s]
# 100%|██████████| 25/25 [00:00<00:00, 501.34it/s]
# Processing points:  90%|█████████ | 9/10 [00:01<00:00,  6.94point/s]
# 100%|██████████| 25/25 [00:00<00:00, 464.19it/s]
# Processing points: 100%|██████████| 10/10 [00:01<00:00,  6.98point/s]

# %%
eigen_model_beef = model_dict['eigen_basis']
eigen_model_beef.fit(input_data=train_data_beef)
eigen_labels_beef = eigen_model_beef.predict(predict_data=test_data_beef)
eigen_probs_beef = eigen_model_beef.predict_proba(predict_data=test_data_beef)
# Out:
# 2024-01-22 13:16:51,301 - Initialising Industrial Repository
# SVD estimation: 100%|██████████| 30/30 [00:00<00:00, 334.22it/s]
# 100%|██████████| 30/30 [00:00<00:00, 151.70it/s]
# 100%|██████████| 30/30 [00:00<00:00, 161.99it/s]
# 100%|██████████| 30/30 [00:00<00:00, 164.37it/s]

# %%
metric_df_eigen_beef = eigen_model_beef.get_metrics(train_data_beef[1],eigen_labels_beef,eigen_probs_beef)
metric_df_eigen_beef
# Out:
#                   0
# accuracy:  0.766667
# f1         0.768825
# roc_auc:   0.914000

# %%
distance = 'euclidean'
explainer = PointExplainer(eigen_model_beef,test_data_beef[0],test_data_beef[1])
explainer.explain(n_samples=5, window=10, method=distance)
explainer.visual(threshold=0, name='Beef')
# Out:
# 100%|██████████| 25/25 [00:00<00:00, 124.71it/s]
# Processing points:   0%|          | 0/10 [00:00<?, ?point/s]
#   0%|          | 0/25 [00:00<?, ?it/s]
# 100%|██████████| 25/25 [00:00<00:00, 125.64it/s]
# Processing points:  10%|█         | 1/10 [00:00<00:04,  1.82point/s]
#   0%|          | 0/25 [00:00<?, ?it/s]
# 100%|██████████| 25/25 [00:00<00:00, 130.21it/s]
# Processing points:  20%|██        | 2/10 [00:01<00:04,  1.82point/s]
#   0%|          | 0/25 [00:00<?, ?it/s]
# 100%|██████████| 25/25 [00:00<00:00, 136.25it/s]
# Processing points:  30%|███       | 3/10 [00:01<00:03,  1.84point/s]
#   0%|          | 0/25 [00:00<?, ?it/s]
# 100%|██████████| 25/25 [00:00<00:00, 140.84it/s]
# Processing points:  40%|████      | 4/10 [00:02<00:03,  1.88point/s]
#   0%|          | 0/25 [00:00<?, ?it/s]
# 100%|██████████| 25/25 [00:00<00:00, 134.77it/s]
# Processing points:  50%|█████     | 5/10 [00:02<00:02,  1.88point/s]
#   0%|          | 0/25 [00:00<?, ?it/s]
# 100%|██████████| 25/25 [00:00<00:00, 140.42it/s]
# Processing points:  60%|██████    | 6/10 [00:03<00:02,  1.90point/s]
#   0%|          | 0/25 [00:00<?, ?it/s]
# 100%|██████████| 25/25 [00:00<00:00, 134.05it/s]
# Processing points:  70%|███████   | 7/10 [00:03<00:01,  1.91point/s]
#   0%|          | 0/25 [00:00<?, ?it/s]
# 100%|██████████| 25/25 [00:00<00:00, 141.62it/s]
# Processing points:  80%|████████  | 8/10 [00:04<00:01,  1.90point/s]
#   0%|          | 0/25 [00:00<?, ?it/s]
# 100%|██████████| 25/25 [00:00<00:00, 131.24it/s]
# Processing points:  90%|█████████ | 9/10 [00:04<00:00,  1.90point/s]
#   0%|          | 0/25 [00:00<?, ?it/s]
# 100%|██████████| 25/25 [00:00<00:00, 135.86it/s]
# Processing points: 100%|██████████| 10/10 [00:05<00:00,  1.88point/s]

# %%
dataset = 'Car'
train_data_car, test_data_car = DataLoader(dataset).load_data()

# %%
from fedot_ind.core.repository.model_repository import default_industrial_availiable_operation
experiment_setup = {'problem': ml_task,
                        'metric': 'accuracy',
                        'timeout': 5,
                        'num_of_generations': 5,
                        'pop_size': 10,
                        'logging_level': 40,
                        'available_operations':default_industrial_availiable_operation(ml_task),
                        'n_jobs': 4,
                        'initial_assumption': None,
                        'max_pipeline_fit_time': 5,
                        'with_tuning': False,
                        'early_stopping_iterations': 5,
                        'early_stopping_timeout': 10,
                        'optimizer': IndustrialEvoOptimizer}
automl_model = FI(**experiment_setup)

# %%
automl_model.fit(input_data=train_data_beef)
automl_model_labels = automl_model.predict(predict_data=test_data_beef)
automl_model_probs = automl_model.predict_proba(predict_data=test_data_beef)
# Out:
# Creating Dask Server
# 2024-01-22 13:44:28,318 - AssumptionsHandler - Memory consumption for fitting of the initial pipeline in main session: current 0.4 MiB, max: 1.0 MiB
# 2024-01-22 13:44:28,319 - ApiComposer - Initial pipeline was fitted in 0.6 sec.
# 2024-01-22 13:44:28,320 - AssumptionsHandler - Preset was changed to best_quality due to fit time estimation for initial model.
# 2024-01-22 13:44:28,329 - ApiComposer - AutoML configured. Parameters tuning: False. Time limit: 5 min. Set of candidate models: ['xgboost', 'logit', 'knn', 'dt', 'rf', 'mlp', 'inception_model', 'omniscale_model', 'resnet_model', 'eigen_basis', 'wavelet_basis', 'fourier_basis', 'topological_extractor', 'quantile_extractor', 'signal_extractor', 'recurrence_extractor', 'minirocket_extractor', 'scaling', 'normalization', 'simple_imputation', 'kernel_pca', 'topological_features'].
# 2024-01-22 13:44:28,357 - ApiComposer - Pipeline composition started.
# Generations:   0%|          | 0/5 [00:00<?, ?gen/s]
# 2024-01-22 13:44:31,994 - IndustrialDispatcher - 2 individuals out of 2 in previous population were evaluated successfully.
# Exception ignored in: <function _WeakKeyDictionary.__setitem__.<locals>.on_destroy at 0x0000022D169E05E0>
# Traceback (most recent call last):
#   File "D:\WORK\Repo\Industiral\IndustrialTS\venv_3.9_new\lib\site-packages\joblib\_dask.py", line 82, in on_destroy
#     del self._data[key]
# KeyError: 2392675469520
# Exception ignored in: <function _WeakKeyDictionary.__setitem__.<locals>.on_destroy at 0x0000022D169D88B0>
# Traceback (most recent call last):
#   File "D:\WORK\Repo\Industiral\IndustrialTS\venv_3.9_new\lib\site-packages\joblib\_dask.py", line 82, in on_destroy
#     del self._data[key]
# KeyError: 2392675059536
#
# SVD estimation: 100%|██████████| 24/24 [00:00<00:00, 276.68it/s]
# Exception ignored in: <function _WeakKeyDictionary.__setitem__.<locals>.on_destroy at 0x0000022D16A2A1F0>
# Traceback (most recent call last):
#   File "D:\WORK\Repo\Industiral\IndustrialTS\venv_3.9_new\lib\site-packages\joblib\_dask.py", line 82, in on_destroy
#     del self._data[key]
# KeyError: 2392676141072
#
# SVD estimation: 100%|██████████| 24/24 [00:00<00:00, 276.60it/s]
# Exception ignored in: <function _WeakKeyDictionary.__setitem__.<locals>.on_destroy at 0x0000022D169E0C10>
# Traceback (most recent call last):
#   File "D:\WORK\Repo\Industiral\IndustrialTS\venv_3.9_new\lib\site-packages\joblib\_dask.py", line 82, in on_destroy
#     del self._data[key]
# KeyError: 2392676640688
#
# SVD estimation: 100%|██████████| 24/24 [00:00<00:00, 292.61it/s]
#
# SVD estimation: 100%|██████████| 24/24 [00:00<00:00, 267.47it/s]
#
# SVD estimation: 100%|██████████| 24/24 [00:00<00:00, 256.21it/s]
# Exception ignored in: <function _WeakKeyDictionary.__setitem__.<locals>.on_destroy at 0x0000022D16F4D550>
# Traceback (most recent call last):
#   File "D:\WORK\Repo\Industiral\IndustrialTS\venv_3.9_new\lib\site-packages\joblib\_dask.py", line 82, in on_destroy
#     del self._data[key]
# KeyError: 2392681656016
# Exception ignored in: <function _WeakKeyDictionary.__setitem__.<locals>.on_destroy at 0x0000022B9CB23F70>
# Traceback (most recent call last):
#   File "D:\WORK\Repo\Industiral\IndustrialTS\venv_3.9_new\lib\site-packages\joblib\_dask.py", line 82, in on_destroy
#     del self._data[key]
# KeyError: 2392560021296
# Exception ignored in: <function _WeakKeyDictionary.__setitem__.<locals>.on_destroy at 0x0000022D16F4D670>
# Traceback (most recent call last):
#   File "D:\WORK\Repo\Industiral\IndustrialTS\venv_3.9_new\lib\site-packages\joblib\_dask.py", line 82, in on_destroy
#     del self._data[key]
# KeyError: 2386340978480
# Exception ignored in: <function _WeakKeyDictionary.__setitem__.<locals>.on_destroy at 0x0000022B9D196CA0>
# Traceback (most recent call last):
#   File "D:\WORK\Repo\Industiral\IndustrialTS\venv_3.9_new\lib\site-packages\joblib\_dask.py", line 82, in on_destroy
#     del self._data[key]
# KeyError: 2392554963568
# Exception ignored in: <function _WeakKeyDictionary.__setitem__.<locals>.on_destroy at 0x0000022CF8B81700>
# Traceback (most recent call last):
#   File "D:\WORK\Repo\Industiral\IndustrialTS\venv_3.9_new\lib\site-packages\joblib\_dask.py", line 82, in on_destroy
#     del self._data[key]
# KeyError: 2392220044048
# Exception ignored in: <function _WeakKeyDictionary.__setitem__.<locals>.on_destroy at 0x0000022B9CFEA670>
# Traceback (most recent call last):
#   File "D:\WORK\Repo\Industiral\IndustrialTS\venv_3.9_new\lib\site-packages\joblib\_dask.py", line 82, in on_destroy
#     del self._data[key]
# KeyError: 2391848651536
# Exception ignored in: <function _WeakKeyDictionary.__setitem__.<locals>.on_destroy at 0x0000022CEBFDDC10>
# Traceback (most recent call last):
#   File "D:\WORK\Repo\Industiral\IndustrialTS\venv_3.9_new\lib\site-packages\joblib\_dask.py", line 82, in on_destroy
#     del self._data[key]
# KeyError: 2386341100304
# 2024-01-22 13:45:23,877 - IndustrialDispatcher - 12 individuals out of 13 in previous population were evaluated successfully.
# Exception ignored in: <function _WeakKeyDictionary.__setitem__.<locals>.on_destroy at 0x0000022D0F5DC790>
# Traceback (most recent call last):
#   File "D:\WORK\Repo\Industiral\IndustrialTS\venv_3.9_new\lib\site-packages\joblib\_dask.py", line 82, in on_destroy
#     del self._data[key]
# KeyError: 2392554471664
# Exception ignored in: <function _WeakKeyDictionary.__setitem__.<locals>.on_destroy at 0x0000022D058385E0>
# Traceback (most recent call last):
#   File "D:\WORK\Repo\Industiral\IndustrialTS\venv_3.9_new\lib\site-packages\joblib\_dask.py", line 82, in on_destroy
#     del self._data[key]
# KeyError: 2392554505296
# Exception ignored in: <function _WeakKeyDictionary.__setitem__.<locals>.on_destroy at 0x0000022D1ED37700>
# Traceback (most recent call last):
#   File "D:\WORK\Repo\Industiral\IndustrialTS\venv_3.9_new\lib\site-packages\joblib\_dask.py", line 82, in on_destroy
#     del self._data[key]
# KeyError: 2392680738320
# Epoch: None, Batch Size: 16, Activation_function: ReLU
# Not enough class samples for validation
# Epoch: 1, Training Loss: 3.57
# Updating learning rate to 4.5571019283953884e-05
# Epoch: 2, Training Loss: 3.52
# Updating learning rate to 6.215475940305631e-05
# Epoch: 3, Training Loss: 3.47
# Updating learning rate to 8.936626895729232e-05
# Epoch: 4, Training Loss: 3.39
# Updating learning rate to 0.0001265738985946948
# Epoch: 5, Training Loss: 3.35
# Updating learning rate to 0.00017291396322267948
# Epoch: 6, Training Loss: 3.25
# Updating learning rate to 0.00022731079036765413
# Epoch: 7, Training Loss: 3.15
# Updating learning rate to 0.0002885016893087411
# Epoch: 8, Training Loss: 3.07
# Updating learning rate to 0.0003550662613875939
# Epoch: 9, Training Loss: 2.91
# Updating learning rate to 0.00042545937112638114
# Epoch: 10, Training Loss: 2.82
# Updating learning rate to 0.0004980470128092187
# Epoch: 11, Training Loss: 2.67
# Updating learning rate to 0.0005711442399711407
# Epoch: 12, Training Loss: 2.56
# Updating learning rate to 0.0006430542773533025
# Epoch: 13, Training Loss: 2.45
# Updating learning rate to 0.0007121079074350134
# Epoch: 14, Training Loss: 2.30
# Updating learning rate to 0.0007767022172795557
# Epoch: 15, Training Loss: 2.23
# Updating learning rate to 0.0008353378062795224
# Epoch: 16, Training Loss: 2.25
# EarlyStopping counter: 1 out of 15
# Updating learning rate to 0.0008866535911138937
# Epoch: 17, Training Loss: 2.19
# Updating learning rate to 0.000929458400003988
# Epoch: 18, Training Loss: 2.05
# Updating learning rate to 0.0009627586228840861
# Epoch: 19, Training Loss: 1.99
# Updating learning rate to 0.000985781275654917
# Epoch: 20, Training Loss: 1.84
# Updating learning rate to 0.0009979919431391726
# Epoch: 21, Training Loss: 1.76
# Updating learning rate to 0.000999844591622044
# Epoch: 22, Training Loss: 1.70
# Updating learning rate to 0.0009980973566564766
# Epoch: 23, Training Loss: 1.59
# Updating learning rate to 0.0009944154354509117
# Epoch: 24, Training Loss: 1.65
# EarlyStopping counter: 1 out of 15
# Updating learning rate to 0.0009888131292073146
# Epoch: 25, Training Loss: 1.55
# Updating learning rate to 0.000981312198226512
# Epoch: 26, Training Loss: 1.50
# Updating learning rate to 0.0009719417773875231
# Epoch: 27, Training Loss: 1.43
# Updating learning rate to 0.00096073826298278
# Epoch: 28, Training Loss: 1.36
# Updating learning rate to 0.0009477451713488011
# Epoch: 29, Training Loss: 1.24
# Updating learning rate to 0.0009330129698414116
# Epoch: 30, Training Loss: 1.25
# EarlyStopping counter: 1 out of 15
# Updating learning rate to 0.0009165988808120355
# Epoch: 31, Training Loss: 1.14
# Updating learning rate to 0.0008985666593464467
# Epoch: 32, Training Loss: 1.03
# Updating learning rate to 0.00087898634562928
# Epoch: 33, Training Loss: 1.08
# EarlyStopping counter: 1 out of 15
# Updating learning rate to 0.0008579339928961606
# Epoch: 34, Training Loss: 0.92
# Updating learning rate to 0.000835491372030129
# Epoch: 35, Training Loss: 0.88
# Updating learning rate to 0.000811745653949763
# Epoch: 36, Training Loss: 0.98
# EarlyStopping counter: 1 out of 15
# Updating learning rate to 0.0007867890710226502
# Epoch: None, Batch Size: 16, Activation_function: ReLU
# Not enough class samples for validation
# Epoch: 1, Training Loss: 3.37
# Updating learning rate to 4.5571019283953884e-05
# Epoch: 2, Training Loss: 3.31
# Updating learning rate to 6.215475940305631e-05
# Epoch: 3, Training Loss: 3.27
# Updating learning rate to 8.936626895729232e-05
# Epoch: 4, Training Loss: 3.24
# Updating learning rate to 0.0001265738985946948
# Epoch: 5, Training Loss: 3.18
# Updating learning rate to 0.00017291396322267948
# Epoch: 6, Training Loss: 3.10
# Updating learning rate to 0.00022731079036765413
# Epoch: 7, Training Loss: 3.03
# Updating learning rate to 0.0002885016893087411
# Epoch: 8, Training Loss: 2.92
# Updating learning rate to 0.0003550662613875939
# Epoch: 9, Training Loss: 2.85
# Updating learning rate to 0.00042545937112638114
# Epoch: 10, Training Loss: 2.74
# Updating learning rate to 0.0004980470128092187
# Epoch: 11, Training Loss: 2.63
# Updating learning rate to 0.0005711442399711407
# Epoch: 12, Training Loss: 2.50
# Updating learning rate to 0.0006430542773533025
# Epoch: 13, Training Loss: 2.40
# Updating learning rate to 0.0007121079074350134
# Epoch: 14, Training Loss: 2.30
# Updating learning rate to 0.0007767022172795557
# Epoch: 15, Training Loss: 2.21
# Updating learning rate to 0.0008353378062795224
# Epoch: 16, Training Loss: 2.12
# Updating learning rate to 0.0008866535911138937
# Epoch: 17, Training Loss: 2.02
# Updating learning rate to 0.000929458400003988
# Epoch: 18, Training Loss: 1.88
# Updating learning rate to 0.0009627586228840861
# Epoch: 19, Training Loss: 1.72
# Updating learning rate to 0.000985781275654917
# Epoch: 20, Training Loss: 1.72
# EarlyStopping counter: 1 out of 15
# Updating learning rate to 0.0009979919431391726
# Epoch: 21, Training Loss: 1.62
# Updating learning rate to 0.000999844591622044
# Epoch: 22, Training Loss: 1.53
# Updating learning rate to 0.0009980973566564766
# Epoch: 23, Training Loss: 1.47
# Updating learning rate to 0.0009944154354509117
# Epoch: 24, Training Loss: 1.36
# Updating learning rate to 0.0009888131292073146
# Epoch: 25, Training Loss: 1.31
# Updating learning rate to 0.000981312198226512
# Epoch: 26, Training Loss: 1.22
# Updating learning rate to 0.0009719417773875231
# Epoch: 27, Training Loss: 1.15
# Updating learning rate to 0.00096073826298278
# Epoch: 28, Training Loss: 1.18
# EarlyStopping counter: 1 out of 15
# Updating learning rate to 0.0009477451713488011
# Epoch: 29, Training Loss: 1.13
# Updating learning rate to 0.0009330129698414116
# Epoch: 30, Training Loss: 0.98
# Updating learning rate to 0.0009165988808120355
# Epoch: 31, Training Loss: 1.03
# EarlyStopping counter: 1 out of 15
# Updating learning rate to 0.0008985666593464467
# Epoch: 32, Training Loss: 1.04
# EarlyStopping counter: 2 out of 15
# Updating learning rate to 0.00087898634562928
# Epoch: 33, Training Loss: 0.97
# Updating learning rate to 0.0008579339928961606
# Epoch: 34, Training Loss: 1.04
# EarlyStopping counter: 1 out of 15
# Updating learning rate to 0.000835491372030129
# Epoch: 35, Training Loss: 0.78
# Updating learning rate to 0.000811745653949763
# Epoch: 36, Training Loss: 0.85
# EarlyStopping counter: 1 out of 15
# Updating learning rate to 0.0007867890710226502
# Epoch: None, Batch Size: 16, Activation_function: ReLU
# Not enough class samples for validation
# Epoch: 1, Training Loss: 3.64
# Updating learning rate to 4.5571019283953884e-05
# Epoch: 2, Training Loss: 3.59
# Updating learning rate to 6.215475940305631e-05
# Epoch: 3, Training Loss: 3.55
# Updating learning rate to 8.936626895729232e-05
# Epoch: 4, Training Loss: 3.49
# Updating learning rate to 0.0001265738985946948
# Epoch: 5, Training Loss: 3.41
# Updating learning rate to 0.00017291396322267948
# Epoch: 6, Training Loss: 3.34
# Updating learning rate to 0.00022731079036765413
# Epoch: 7, Training Loss: 3.24
# Updating learning rate to 0.0002885016893087411
# Epoch: 8, Training Loss: 3.11
# Updating learning rate to 0.0003550662613875939
# Epoch: 9, Training Loss: 3.03
# Updating learning rate to 0.00042545937112638114
# Epoch: 10, Training Loss: 2.91
# Updating learning rate to 0.0004980470128092187
# Epoch: 11, Training Loss: 2.82
# Updating learning rate to 0.0005711442399711407
# Epoch: 12, Training Loss: 2.68
# Updating learning rate to 0.0006430542773533025
# Epoch: 13, Training Loss: 2.57
# Updating learning rate to 0.0007121079074350134
# Epoch: 14, Training Loss: 2.49
# Updating learning rate to 0.0007767022172795557
# Epoch: 15, Training Loss: 2.34
# Updating learning rate to 0.0008353378062795224
# Epoch: 16, Training Loss: 2.27
# Updating learning rate to 0.0008866535911138937
# Epoch: 17, Training Loss: 2.18
# Updating learning rate to 0.000929458400003988
# Epoch: 18, Training Loss: 2.09
# Updating learning rate to 0.0009627586228840861
# Epoch: 19, Training Loss: 2.00
# Updating learning rate to 0.000985781275654917
# Epoch: 20, Training Loss: 1.89
# Updating learning rate to 0.0009979919431391726
# Epoch: 21, Training Loss: 1.82
# Updating learning rate to 0.000999844591622044
# Epoch: 22, Training Loss: 1.77
# Updating learning rate to 0.0009980973566564766
# Epoch: 23, Training Loss: 1.68
# Updating learning rate to 0.0009944154354509117
# Epoch: 24, Training Loss: 1.59
# Updating learning rate to 0.0009888131292073146
# Epoch: 25, Training Loss: 1.51
# Updating learning rate to 0.000981312198226512
# Epoch: 26, Training Loss: 1.38
# Updating learning rate to 0.0009719417773875231
# Epoch: 27, Training Loss: 1.37
# Updating learning rate to 0.00096073826298278
# Epoch: 28, Training Loss: 1.30
# Updating learning rate to 0.0009477451713488011
# Epoch: 29, Training Loss: 1.26
# Updating learning rate to 0.0009330129698414116
# Epoch: 30, Training Loss: 1.14
# Updating learning rate to 0.0009165988808120355
# Epoch: 31, Training Loss: 1.25
# EarlyStopping counter: 1 out of 15
# Updating learning rate to 0.0008985666593464467
# Epoch: 32, Training Loss: 1.17
# EarlyStopping counter: 2 out of 15
# Updating learning rate to 0.00087898634562928
# Epoch: 33, Training Loss: 1.05
# Updating learning rate to 0.0008579339928961606
# Epoch: 34, Training Loss: 0.98
# Updating learning rate to 0.000835491372030129
# Epoch: 35, Training Loss: 0.99
# EarlyStopping counter: 1 out of 15
# Updating learning rate to 0.000811745653949763
# Epoch: 36, Training Loss: 0.93
# Updating learning rate to 0.0007867890710226502
# Epoch: None, Batch Size: 16, Activation_function: ReLU
# Not enough class samples for validation
# Epoch: 1, Training Loss: 3.37
# Updating learning rate to 4.5571019283953884e-05
# Epoch: 2, Training Loss: 3.30
# Updating learning rate to 6.215475940305631e-05
# Epoch: 3, Training Loss: 3.24
# Updating learning rate to 8.936626895729232e-05
# Epoch: 4, Training Loss: 3.20
# Updating learning rate to 0.0001265738985946948
# Epoch: 5, Training Loss: 3.14
# Updating learning rate to 0.00017291396322267948
# Epoch: 6, Training Loss: 3.05
# Updating learning rate to 0.00022731079036765413
# Epoch: 7, Training Loss: 2.96
# Updating learning rate to 0.0002885016893087411
# Epoch: 8, Training Loss: 2.85
# Updating learning rate to 0.0003550662613875939
# Epoch: 9, Training Loss: 2.73
# Updating learning rate to 0.00042545937112638114
# Epoch: 10, Training Loss: 2.62
# Updating learning rate to 0.0004980470128092187
# Epoch: 11, Training Loss: 2.50
# Updating learning rate to 0.0005711442399711407
# Epoch: 12, Training Loss: 2.41
# Updating learning rate to 0.0006430542773533025
# Epoch: 13, Training Loss: 2.33
# Updating learning rate to 0.0007121079074350134
# Epoch: 14, Training Loss: 2.20
# Updating learning rate to 0.0007767022172795557
# Epoch: 15, Training Loss: 2.14
# Updating learning rate to 0.0008353378062795224
# Epoch: 16, Training Loss: 2.06
# Updating learning rate to 0.0008866535911138937
# Epoch: 17, Training Loss: 1.94
# Updating learning rate to 0.000929458400003988
# Epoch: 18, Training Loss: 1.91
# Updating learning rate to 0.0009627586228840861
# Epoch: 19, Training Loss: 1.82
# Updating learning rate to 0.000985781275654917
# Epoch: 20, Training Loss: 1.73
# Updating learning rate to 0.0009979919431391726
# Epoch: 21, Training Loss: 1.63
# Updating learning rate to 0.000999844591622044
# Epoch: 22, Training Loss: 1.60
# Updating learning rate to 0.0009980973566564766
# Epoch: 23, Training Loss: 1.48
# Updating learning rate to 0.0009944154354509117
# Epoch: 24, Training Loss: 1.45
# Updating learning rate to 0.0009888131292073146
# Epoch: 25, Training Loss: 1.30
# Updating learning rate to 0.000981312198226512
# Epoch: 26, Training Loss: 1.23
# Updating learning rate to 0.0009719417773875231
# Epoch: 27, Training Loss: 1.11
# Updating learning rate to 0.00096073826298278
# Epoch: 28, Training Loss: 1.05
# Updating learning rate to 0.0009477451713488011
# Epoch: 29, Training Loss: 0.94
# Updating learning rate to 0.0009330129698414116
# Epoch: 30, Training Loss: 0.90
# Updating learning rate to 0.0009165988808120355
# Epoch: 31, Training Loss: 0.84
# Updating learning rate to 0.0008985666593464467
# Epoch: 32, Training Loss: 0.77
# Updating learning rate to 0.00087898634562928
# Epoch: 33, Training Loss: 0.70
# Updating learning rate to 0.0008579339928961606
# Epoch: 34, Training Loss: 0.68
# Updating learning rate to 0.000835491372030129
# Epoch: 35, Training Loss: 0.63
# Updating learning rate to 0.000811745653949763
# Epoch: 36, Training Loss: 0.80
# EarlyStopping counter: 1 out of 15
# Updating learning rate to 0.0007867890710226502
# Epoch: None, Batch Size: 16, Activation_function: ReLU
# Not enough class samples for validation
# Epoch: 1, Training Loss: 3.10
# Updating learning rate to 4.5571019283953884e-05
# Epoch: 2, Training Loss: 3.03
# Updating learning rate to 6.215475940305631e-05
# Epoch: 3, Training Loss: 2.97
# Updating learning rate to 8.936626895729232e-05
# Epoch: 4, Training Loss: 2.97
# Updating learning rate to 0.0001265738985946948
# Epoch: 5, Training Loss: 2.90
# Updating learning rate to 0.00017291396322267948
# Epoch: 6, Training Loss: 2.85
# Updating learning rate to 0.00022731079036765413
# Epoch: 7, Training Loss: 2.75
# Updating learning rate to 0.0002885016893087411
# Epoch: 8, Training Loss: 2.70
# Updating learning rate to 0.0003550662613875939
# Epoch: 9, Training Loss: 2.56
# Updating learning rate to 0.00042545937112638114
# Epoch: 10, Training Loss: 2.45
# Updating learning rate to 0.0004980470128092187
# Epoch: 11, Training Loss: 2.33
# Updating learning rate to 0.0005711442399711407
# Epoch: 12, Training Loss: 2.22
# Updating learning rate to 0.0006430542773533025
# Epoch: 13, Training Loss: 2.10
# Updating learning rate to 0.0007121079074350134
# Epoch: 14, Training Loss: 2.10
# EarlyStopping counter: 1 out of 15
# Updating learning rate to 0.0007767022172795557
# Epoch: 15, Training Loss: 1.92
# Updating learning rate to 0.0008353378062795224
# Epoch: 16, Training Loss: 1.85
# Updating learning rate to 0.0008866535911138937
# Epoch: 17, Training Loss: 1.74
# Updating learning rate to 0.000929458400003988
# Epoch: 18, Training Loss: 1.83
# EarlyStopping counter: 1 out of 15
# Updating learning rate to 0.0009627586228840861
# Epoch: 19, Training Loss: 1.82
# EarlyStopping counter: 2 out of 15
# Updating learning rate to 0.000985781275654917
# Epoch: 20, Training Loss: 1.64
# Updating learning rate to 0.0009979919431391726
# Epoch: 21, Training Loss: 1.52
# Updating learning rate to 0.000999844591622044
# Epoch: 22, Training Loss: 1.41
# Updating learning rate to 0.0009980973566564766
# Epoch: 23, Training Loss: 1.42
# EarlyStopping counter: 1 out of 15
# Updating learning rate to 0.0009944154354509117
# Epoch: 24, Training Loss: 1.30
# Updating learning rate to 0.0009888131292073146
# Epoch: 25, Training Loss: 1.18
# Updating learning rate to 0.000981312198226512
# Epoch: 26, Training Loss: 1.10
# Updating learning rate to 0.0009719417773875231
# Epoch: 27, Training Loss: 1.09
# Updating learning rate to 0.00096073826298278
# Epoch: 28, Training Loss: 1.04
# Updating learning rate to 0.0009477451713488011
# Epoch: 29, Training Loss: 1.10
# EarlyStopping counter: 1 out of 15
# Updating learning rate to 0.0009330129698414116
# Epoch: 30, Training Loss: 1.10
# EarlyStopping counter: 2 out of 15
# Updating learning rate to 0.0009165988808120355
# Epoch: 31, Training Loss: 0.95
# Updating learning rate to 0.0008985666593464467
# Epoch: 32, Training Loss: 0.89
# Updating learning rate to 0.00087898634562928
# Epoch: 33, Training Loss: 0.86
# Updating learning rate to 0.0008579339928961606
# Epoch: 34, Training Loss: 0.93
# EarlyStopping counter: 1 out of 15
# Updating learning rate to 0.000835491372030129
# Epoch: 35, Training Loss: 1.14
# EarlyStopping counter: 2 out of 15
# Updating learning rate to 0.000811745653949763
# Epoch: 36, Training Loss: 0.89
# EarlyStopping counter: 3 out of 15
# Updating learning rate to 0.0007867890710226502
# Exception ignored in: <function _WeakKeyDictionary.__setitem__.<locals>.on_destroy at 0x0000022D16B94670>
# Traceback (most recent call last):
#   File "D:\WORK\Repo\Industiral\IndustrialTS\venv_3.9_new\lib\site-packages\joblib\_dask.py", line 82, in on_destroy
#     del self._data[key]
# KeyError: 2392677970544
# Exception ignored in: <function _WeakKeyDictionary.__setitem__.<locals>.on_destroy at 0x0000022B9CFEA820>
# Traceback (most recent call last):
#   File "D:\WORK\Repo\Industiral\IndustrialTS\venv_3.9_new\lib\site-packages\joblib\_dask.py", line 82, in on_destroy
#     del self._data[key]
# KeyError: 2392389777328
# Exception ignored in: <function _WeakKeyDictionary.__setitem__.<locals>.on_destroy at 0x0000022B9CFEA160>
# Traceback (most recent call last):
#   File "D:\WORK\Repo\Industiral\IndustrialTS\venv_3.9_new\lib\site-packages\joblib\_dask.py", line 82, in on_destroy
#     del self._data[key]
# KeyError: 2392219523952
# Exception ignored in: <function _WeakKeyDictionary.__setitem__.<locals>.on_destroy at 0x0000022B9CF844C0>
# Traceback (most recent call last):
#   File "D:\WORK\Repo\Industiral\IndustrialTS\venv_3.9_new\lib\site-packages\joblib\_dask.py", line 82, in on_destroy
#     del self._data[key]
# KeyError: 2392220043760
# Exception ignored in: <function _WeakKeyDictionary.__setitem__.<locals>.on_destroy at 0x0000022D1ED37700>
# Traceback (most recent call last):
#   File "D:\WORK\Repo\Industiral\IndustrialTS\venv_3.9_new\lib\site-packages\joblib\_dask.py", line 82, in on_destroy
#     del self._data[key]
# KeyError: 2392317739344
# Exception ignored in: <function _WeakKeyDictionary.__setitem__.<locals>.on_destroy at 0x0000022B9CF84C10>
# Traceback (most recent call last):
#   File "D:\WORK\Repo\Industiral\IndustrialTS\venv_3.9_new\lib\site-packages\joblib\_dask.py", line 82, in on_destroy
#     del self._data[key]
# KeyError: 2392389777328
# Exception ignored in: <function _WeakKeyDictionary.__setitem__.<locals>.on_destroy at 0x0000022D16B21AF0>
# Traceback (most recent call last):
#   File "D:\WORK\Repo\Industiral\IndustrialTS\venv_3.9_new\lib\site-packages\joblib\_dask.py", line 82, in on_destroy
#     del self._data[key]
# KeyError: 2386340884624
# Exception ignored in: <function _WeakKeyDictionary.__setitem__.<locals>.on_destroy at 0x0000022D1ED7A4C0>
# Traceback (most recent call last):
#   File "D:\WORK\Repo\Industiral\IndustrialTS\venv_3.9_new\lib\site-packages\joblib\_dask.py", line 82, in on_destroy
#     del self._data[key]
# KeyError: 2392687335440
#
#   0%|          | 0/24 [00:00<?, ?it/s]
#  50%|█████     | 12/24 [00:00<00:00, 14.03it/s]
#  75%|███████▌  | 18/24 [00:01<00:00, 12.03it/s]
# 100%|██████████| 24/24 [00:02<00:00, 11.64it/s]
# Exception ignored in: <function _WeakKeyDictionary.__setitem__.<locals>.on_destroy at 0x0000022D0F6629D0>
# Traceback (most recent call last):
#   File "D:\WORK\Repo\Industiral\IndustrialTS\venv_3.9_new\lib\site-packages\joblib\_dask.py", line 82, in on_destroy
#     del self._data[key]
# KeyError: 2392389402416
#
# 100%|██████████| 6/6 [00:00<00:00, 3008.11it/s]
#
#   0%|          | 0/24 [00:00<?, ?it/s]
#  50%|█████     | 12/24 [00:00<00:00, 19.76it/s]
#  75%|███████▌  | 18/24 [00:01<00:00, 14.05it/s]
# 100%|██████████| 24/24 [00:01<00:00, 13.07it/s]
#
# 100%|██████████| 6/6 [00:00<00:00, 6017.65it/s]
#
#   0%|          | 0/24 [00:00<?, ?it/s]
#  50%|█████     | 12/24 [00:00<00:00, 19.37it/s]
#  75%|███████▌  | 18/24 [00:01<00:00, 14.04it/s]
# 100%|██████████| 24/24 [00:01<00:00, 13.31it/s]
# Exception ignored in: <function _WeakKeyDictionary.__setitem__.<locals>.on_destroy at 0x0000022D17216DC0>
# Traceback (most recent call last):
#   File "D:\WORK\Repo\Industiral\IndustrialTS\venv_3.9_new\lib\site-packages\joblib\_dask.py", line 82, in on_destroy
#     del self._data[key]
# KeyError: 2392677041424
#
# 100%|██████████| 6/6 [00:00<00:00, 5840.29it/s]
#
#   0%|          | 0/24 [00:00<?, ?it/s]
#  50%|█████     | 12/24 [00:00<00:00, 19.59it/s]
#  75%|███████▌  | 18/24 [00:01<00:00, 14.03it/s]
# 100%|██████████| 24/24 [00:01<00:00, 13.04it/s]
# Exception ignored in: <function _WeakKeyDictionary.__setitem__.<locals>.on_destroy at 0x0000022D1727F430>
# Traceback (most recent call last):
#   File "D:\WORK\Repo\Industiral\IndustrialTS\venv_3.9_new\lib\site-packages\joblib\_dask.py", line 82, in on_destroy
#     del self._data[key]
# KeyError: 2392684061872
#
# 100%|██████████| 6/6 [00:00<00:00, 1993.33it/s]
#
#   0%|          | 0/24 [00:00<?, ?it/s]
#  50%|█████     | 12/24 [00:00<00:00, 20.19it/s]
#  75%|███████▌  | 18/24 [00:01<00:00, 14.42it/s]
# 100%|██████████| 24/24 [00:01<00:00, 13.66it/s]
# Exception ignored in: <function _WeakKeyDictionary.__setitem__.<locals>.on_destroy at 0x0000022D1ED37CA0>
# Traceback (most recent call last):
#   File "D:\WORK\Repo\Industiral\IndustrialTS\venv_3.9_new\lib\site-packages\joblib\_dask.py", line 82, in on_destroy
#     del self._data[key]
# KeyError: 2392817045552
#
# 100%|██████████| 6/6 [00:00<00:00, 2965.92it/s]
#
# 100%|██████████| 24/24 [00:00<00:00, 388.13it/s]
#
# 100%|██████████| 6/6 [00:00<00:00, 1195.02it/s]
# Exception ignored in: <function _WeakKeyDictionary.__setitem__.<locals>.on_destroy at 0x0000022D058159D0>
# Traceback (most recent call last):
#   File "D:\WORK\Repo\Industiral\IndustrialTS\venv_3.9_new\lib\site-packages\joblib\_dask.py", line 82, in on_destroy
#     del self._data[key]
# KeyError: 2392819660912
#
# 100%|██████████| 24/24 [00:00<00:00, 429.71it/s]
#
# 100%|██████████| 6/6 [00:00<00:00, 3007.75it/s]
#
# 100%|██████████| 24/24 [00:00<00:00, 462.52it/s]
#
# 100%|██████████| 6/6 [00:00<00:00, 2966.27it/s]
#
# 100%|██████████| 24/24 [00:00<00:00, 471.85it/s]
#
# 100%|██████████| 6/6 [00:00<00:00, 3036.42it/s]
#
# 100%|██████████| 24/24 [00:00<00:00, 438.19it/s]
#
# 100%|██████████| 6/6 [00:00<00:00, 1987.04it/s]
# 2024-01-22 13:48:11,921 - IndustrialDispatcher - 11 individuals out of 11 in previous population were evaluated successfully.
# 2024-01-22 13:48:12,695 - DataOperation - Can not find evaluation strategy because of Impossible to obtain <class 'fedot_ind.core.operation.interfaces.industrial_preprocessing_strategy.IndustrialClassificationPreprocessingStrategy'> strategy for topological_features
# Exception ignored in: <function _WeakKeyDictionary.__setitem__.<locals>.on_destroy at 0x0000022D1EF411F0>
# Traceback (most recent call last):
#   File "D:\WORK\Repo\Industiral\IndustrialTS\venv_3.9_new\lib\site-packages\joblib\_dask.py", line 82, in on_destroy
#     del self._data[key]
# KeyError: 2392815682640
# Exception ignored in: <function _WeakKeyDictionary.__setitem__.<locals>.on_destroy at 0x0000022D1F11E5E0>
# Traceback (most recent call last):
#   File "D:\WORK\Repo\Industiral\IndustrialTS\venv_3.9_new\lib\site-packages\joblib\_dask.py", line 82, in on_destroy
#     del self._data[key]
# KeyError: 2392814307632
# Exception ignored in: <function _WeakKeyDictionary.__setitem__.<locals>.on_destroy at 0x0000022D249ACCA0>
# Traceback (most recent call last):
#   File "D:\WORK\Repo\Industiral\IndustrialTS\venv_3.9_new\lib\site-packages\joblib\_dask.py", line 82, in on_destroy
#     del self._data[key]
# KeyError: 2386340598384
# Exception ignored in: <function _WeakKeyDictionary.__setitem__.<locals>.on_destroy at 0x0000022D2498D280>
# Traceback (most recent call last):
#   File "D:\WORK\Repo\Industiral\IndustrialTS\venv_3.9_new\lib\site-packages\joblib\_dask.py", line 82, in on_destroy
#     del self._data[key]
# KeyError: 2392676639248
#
#   0%|          | 0/24 [00:00<?, ?it/s]
#  50%|█████     | 12/24 [00:00<00:00, 58.41it/s]
#  75%|███████▌  | 18/24 [00:00<00:00, 42.44it/s]
# 100%|██████████| 24/24 [00:00<00:00, 39.00it/s]
#
# 100%|██████████| 6/6 [00:00<00:00, 1002.66it/s]
#
#   0%|          | 0/24 [00:00<?, ?it/s]
#  50%|█████     | 12/24 [00:00<00:00, 58.14it/s]
#  75%|███████▌  | 18/24 [00:00<00:00, 42.48it/s]
# 100%|██████████| 24/24 [00:00<00:00, 39.07it/s]
#
# 100%|██████████| 6/6 [00:00<00:00, 2962.78it/s]
#
#   0%|          | 0/24 [00:00<?, ?it/s]
#  50%|█████     | 12/24 [00:00<00:00, 58.13it/s]
#  75%|███████▌  | 18/24 [00:00<00:00, 42.60it/s]
# 100%|██████████| 24/24 [00:00<00:00, 39.71it/s]
#
# 100%|██████████| 6/6 [00:00<00:00, 1987.35it/s]
#
#   0%|          | 0/24 [00:00<?, ?it/s]
#  50%|█████     | 12/24 [00:00<00:00, 57.30it/s]
#  75%|███████▌  | 18/24 [00:00<00:00, 41.73it/s]
# 100%|██████████| 24/24 [00:00<00:00, 38.28it/s]
#
# 100%|██████████| 6/6 [00:00<00:00, 2005.72it/s]
# Exception ignored in: <function _WeakKeyDictionary.__setitem__.<locals>.on_destroy at 0x0000022D16A75310>
# Traceback (most recent call last):
#   File "D:\WORK\Repo\Industiral\IndustrialTS\venv_3.9_new\lib\site-packages\joblib\_dask.py", line 82, in on_destroy
#     del self._data[key]
# KeyError: 2386342418352
#
#   0%|          | 0/24 [00:00<?, ?it/s]
#  50%|█████     | 12/24 [00:00<00:00, 58.98it/s]
#  75%|███████▌  | 18/24 [00:00<00:00, 43.00it/s]
# 100%|██████████| 24/24 [00:00<00:00, 39.51it/s]
#
# 100%|██████████| 6/6 [00:00<00:00, 1982.50it/s]
# 2024-01-22 13:49:05,017 - IndustrialDispatcher - 6 individuals out of 7 in previous population were evaluated successfully.
#   0%|          | 0/24 [00:00<?, ?it/s]
# 100%|██████████| 24/24 [00:00<00:00, 153.32it/s]
#
# 100%|██████████| 6/6 [00:00<00:00, 3065.26it/s]
# Exception ignored in: <function _WeakKeyDictionary.__setitem__.<locals>.on_destroy at 0x0000022D1EC4E940>
# Traceback (most recent call last):
#   File "D:\WORK\Repo\Industiral\IndustrialTS\venv_3.9_new\lib\site-packages\joblib\_dask.py", line 82, in on_destroy
#     del self._data[key]
# KeyError: 2392817045744
#
#   0%|          | 0/24 [00:00<?, ?it/s]
# 100%|██████████| 24/24 [00:00<00:00, 157.28it/s]
#
# 100%|██████████| 6/6 [00:00<00:00, 3016.40it/s]
# Exception ignored in: <function _WeakKeyDictionary.__setitem__.<locals>.on_destroy at 0x0000022D1707C820>
# Traceback (most recent call last):
#   File "D:\WORK\Repo\Industiral\IndustrialTS\venv_3.9_new\lib\site-packages\joblib\_dask.py", line 82, in on_destroy
#     del self._data[key]
# KeyError: 2388001742736
# Exception ignored in: <function _WeakKeyDictionary.__setitem__.<locals>.on_destroy at 0x0000022D058BB160>
# Traceback (most recent call last):
#   File "D:\WORK\Repo\Industiral\IndustrialTS\venv_3.9_new\lib\site-packages\joblib\_dask.py", line 82, in on_destroy
#     del self._data[key]
# KeyError: 2392317370608
#
#   0%|          | 0/24 [00:00<?, ?it/s]
# 100%|██████████| 24/24 [00:00<00:00, 159.39it/s]
# Exception ignored in: <function _WeakKeyDictionary.__setitem__.<locals>.on_destroy at 0x0000022D21B685E0>
# Traceback (most recent call last):
#   File "D:\WORK\Repo\Industiral\IndustrialTS\venv_3.9_new\lib\site-packages\joblib\_dask.py", line 82, in on_destroy
#     del self._data[key]
# KeyError: 2392390856496
#
# 100%|██████████| 6/6 [00:00<00:00, 3008.11it/s]
# Exception ignored in: <function _WeakKeyDictionary.__setitem__.<locals>.on_destroy at 0x0000022D24C36550>
# Traceback (most recent call last):
#   File "D:\WORK\Repo\Industiral\IndustrialTS\venv_3.9_new\lib\site-packages\joblib\_dask.py", line 82, in on_destroy
#     del self._data[key]
# KeyError: 2387982664688
#
#   0%|          | 0/24 [00:00<?, ?it/s]
# 100%|██████████| 24/24 [00:00<00:00, 160.47it/s]
#
# 100%|██████████| 6/6 [00:00<00:00, 2954.43it/s]
# Exception ignored in: <function _WeakKeyDictionary.__setitem__.<locals>.on_destroy at 0x0000022D24C69C10>
# Traceback (most recent call last):
#   File "D:\WORK\Repo\Industiral\IndustrialTS\venv_3.9_new\lib\site-packages\joblib\_dask.py", line 82, in on_destroy
#     del self._data[key]
# KeyError: 2386340886736
#
#   0%|          | 0/24 [00:00<?, ?it/s]
# 100%|██████████| 24/24 [00:00<00:00, 163.70it/s]
# Exception ignored in: <function _WeakKeyDictionary.__setitem__.<locals>.on_destroy at 0x0000022B9A8B2A60>
# Traceback (most recent call last):
#   File "D:\WORK\Repo\Industiral\IndustrialTS\venv_3.9_new\lib\site-packages\joblib\_dask.py", line 82, in on_destroy
#     del self._data[key]
# KeyError: 2392817963536
#
# 100%|██████████| 6/6 [00:00<00:00, 3007.39it/s]
# Exception ignored in: <function _WeakKeyDictionary.__setitem__.<locals>.on_destroy at 0x0000022B9A907550>
# Traceback (most recent call last):
#   File "D:\WORK\Repo\Industiral\IndustrialTS\venv_3.9_new\lib\site-packages\joblib\_dask.py", line 82, in on_destroy
#     del self._data[key]
# KeyError: 2392554320496
# Exception ignored in: <function _WeakKeyDictionary.__setitem__.<locals>.on_destroy at 0x0000022B9A944550>
# Traceback (most recent call last):
#   File "D:\WORK\Repo\Industiral\IndustrialTS\venv_3.9_new\lib\site-packages\joblib\_dask.py", line 82, in on_destroy
#     del self._data[key]
# KeyError: 2387982801104
# Exception ignored in: <function _WeakKeyDictionary.__setitem__.<locals>.on_destroy at 0x0000022B9BB87160>
# Traceback (most recent call last):
#   File "D:\WORK\Repo\Industiral\IndustrialTS\venv_3.9_new\lib\site-packages\joblib\_dask.py", line 82, in on_destroy
#     del self._data[key]
# KeyError: 2386342346992
#
# SVD estimation: 100%|██████████| 24/24 [00:00<00:00, 262.95it/s]
#
# SVD estimation: 100%|██████████| 24/24 [00:00<00:00, 251.58it/s]
#
# SVD estimation: 100%|██████████| 24/24 [00:00<00:00, 290.52it/s]
#
# SVD estimation: 100%|██████████| 24/24 [00:00<00:00, 292.55it/s]
# Exception ignored in: <function _WeakKeyDictionary.__setitem__.<locals>.on_destroy at 0x0000022B9C198A60>
# Traceback (most recent call last):
#   File "D:\WORK\Repo\Industiral\IndustrialTS\venv_3.9_new\lib\site-packages\joblib\_dask.py", line 82, in on_destroy
#     del self._data[key]
# KeyError: 2392554602288
#
# SVD estimation: 100%|██████████| 24/24 [00:00<00:00, 290.24it/s]
# Exception ignored in: <function _WeakKeyDictionary.__setitem__.<locals>.on_destroy at 0x0000022D1F11E550>
# Traceback (most recent call last):
#   File "D:\WORK\Repo\Industiral\IndustrialTS\venv_3.9_new\lib\site-packages\joblib\_dask.py", line 82, in on_destroy
#     del self._data[key]
# KeyError: 2392389479184
# 2024-01-22 13:49:29,259 - IndustrialDispatcher - 3 individuals out of 3 in previous population were evaluated successfully.
# Generations:  20%|██        | 1/5 [05:00<20:03, 300.91s/gen]
# 2024-01-22 13:49:29,328 - GroupedCondition - Optimisation stopped: Time limit is reached
# Generations:  20%|██        | 1/5 [05:00<20:03, 300.97s/gen]
# 2024-01-22 13:49:29,544 - ApiComposer - Model generation finished
# 2024-01-22 13:49:29,627 - FEDOT logger - Final pipeline was fitted
# 2024-01-22 13:49:29,629 - FEDOT logger - Final pipeline: {'depth': 1, 'length': 1, 'nodes': [logit]}
# logit - {}
# 2024-01-22 13:49:29,630 - MemoryAnalytics - Memory consumption for finish in main session: current 42.2 MiB, max: 63.5 MiB

# %%
metric_df_automl_beef = automl_model.get_metrics(train_data_beef[1],automl_model_labels,automl_model_probs)
metric_df_automl_beef
# Out:
#                   0
# accuracy:  0.800000
# f1         0.797396
# roc_auc:   0.933000

# %%
explainer_auto_car = PointExplainer(automl_model, test_data_beef[0], test_data_beef[1])
explainer_auto_car.explain(n_samples=5, window=10, method='euclidean')
explainer_auto_car.visual(threshold=0, name='Beef'+'_'+'automl')
# Out:
# Processing points: 100%|██████████| 10/10 [00:00<00:00, 455.77point/s]

# %% [markdown]
# ## SHAP (SHapley Additive exPlanations)

# %% [markdown]
# SHAP values offer a game-theoretic approach to assign a value to each feature's contribution to a model's prediction.
# In the context of time series, SHAP values can be calculated for individual time points or across the entire sequence. The formula for calculating SHAP values is given by:

# %% [markdown]
# $$\phi_i(f) = \sum_{S \subseteq N \setminus \{i\}} \frac{{|S| - 1}! \cdot (|N| - |S| - 1)!}{|N|!} [f(S \cup \{i\}) - f(S)] $$
#
# where:
#
# - $f(S)$ is the model's output when considering only the features in set $S$,
# - $N$ is the set of all features, and
# - $i$ is the feature for which we are calculating the SHAP value.

# %% [markdown]
# In our case for statistical model we can explore SHAP values for each feature, extracted by QuantileExtractor. Here they are:

# %% [markdown]
# ## Time Series Points Perturbation Analysis

# %% [markdown]
# Perturbation analysis involves systematically perturbing features and observing the impact on predictions. In time series, this can be applied by introducing small changes to the input features at each time point and monitoring the resulting variations in the model output. By quantifying the sensitivity of the model to perturbations, insights into feature importance and model behavior can be gained.

# %%
from fedot_ind.tools.explain.explain import PointExplainer

distance = 'euclidean'
explainer = PointExplainer(automl_model,test_data_beef[0],test_data_beef[1])
explainer.explain(n_samples=5, window=10, method=distance)
explainer.visual(threshold=0, name=dataset+'_'+distance)
# Out:
# Processing points: 100%|██████████| 10/10 [00:00<00:00, 527.72point/s]

# %%
distance = 'cross_entropy'
explainer = PointExplainer(automl_model,test_data_beef[0],test_data_beef[1])
explainer.explain(n_samples=1, window=10, method=distance)
explainer.visual(threshold=0, name=dataset+'_'+distance)
# Out:
# Processing points: 100%|██████████| 10/10 [00:00<00:00, 501.57point/s]

# %%
distance = 'rmse'
explainer = PointExplainer(automl_model,test_data_beef[0],test_data_beef[1])
explainer.explain(n_samples=1, window=10, method=distance)
explainer.visual(threshold=0, name=dataset+'_'+distance)
# Out:
# Processing points: 100%|██████████| 10/10 [00:00<00:00, 435.93point/s]
