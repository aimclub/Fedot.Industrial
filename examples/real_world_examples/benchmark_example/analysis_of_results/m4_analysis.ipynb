# %% [markdown]
# # M4 Forecasting Benchmark Analysis
#
# Thin notebook entrypoint backed by `benchmark.industrial` result analysis utilities and Kernel Learning reference configs.

# %%
from benchmark import industrial as industrial_benchmark
from examples.real_world_examples.benchmark_example.analysis_of_results.current_api import (
    build_current_model_specs,
    build_kernel_learning_reference_model_specs,
    build_ucr_two_stage_context,
    preflight_summary,
    render_analysis_notebook_pack,
    render_forecasting_model_comparison_pack,
)

ANALYSIS_NAME = "m4_analysis"
TASK_TYPE = "forecasting"
preflight_summary()
# Out:
# {'version': 'industrial_real_world_analysis@1',
#  'available_analyses': ('analysis_multi_clf',
#   'analysis_regr',
#   'analysis_uni_clf',
#   'm4_analysis',
#   'pdl_uni_benchmark'),
#  'feature_generators': ('quantile_extractor_torch',
#   'wavelet_extractor',
#   'fourier_extractor',
#   'eigen_extractor',
#   'minirocket_extractor'),
#  'analysis_sources': {'analysis_uni_clf': ('benchmark/results/time_series_uni_clf_comparasion_2024.csv',
#    'benchmark/results/v2_kernel_learning/ucr_suite_020626'),
#   'analysis_multi_clf': ('benchmark/results/time_series_multI_clf_comparasion_241223.csv',),
#   'analysis_regr': ('benchmark/results/time_series_multi_reg_comparasion_2024.csv',
#    'benchmark/results/kernel_learning/tser_full'),
#   'm4_analysis': ('benchmark/results/kernel_learning/m4_full',),
#   'pdl_uni_benchmark': ('benchmark/results/time_series_uni_clf_comparasion_2024.csv',
#    'benchmark/results/v2_kernel_learning/ucr_suite_020626',
#    'benchmark/results/kernel_learning/pdl_ucr_full')},
#  'external_sources': {'composition_results': {'path': 'examples/utils/data/benchmark_history/real_world_archive/composition_results',
#    'task_type': 'mixed',
#    'source_label': 'fedot_industrial_evolution_history',
#    'dvc_key': 'real_world_archive_composition_results',
#    'absolute_path': 'D:\\data_old\\WORK\\Repo\\Industiral\\IndustrialTS\\examples\\utils\\data\\benchmark_history\\real_world_archive\\composition_results',
#    'exists_locally': True},
#   'm3_m4_data': {'path': 'examples/utils/data/benchmark_history/real_world_archive/data',
#    'task_type': 'forecasting',
#    'source_label': 'local_m3_m4_archive_data',
#    'dvc_key': 'real_world_archive_m3_m4_data',
#    'absolute_path': 'D:\\data_old\\WORK\\Repo\\Industiral\\IndustrialTS\\examples\\utils\\data\\benchmark_history\\real_world_archive\\data',
#    'exists_locally': True},
#   'forecasting_progress_items': {'path': 'benchmark/results/v2_kernel_learning/forecasting_suite_140526/kernel_learning_forecasting_suite_f184092168',
#    'task_type': 'forecasting',
#    'source_label': 'industrial_kernel_learning_m4_monthly_progress',
#    'dataset_name': 'm4_monthly_kernel_learning',
#    'series_id': 'M1779',
#    'absolute_path': 'D:\\data_old\\WORK\\Repo\\Industiral\\IndustrialTS\\benchmark\\results\\v2_kernel_learning\\forecasting_suite_140526\\kernel_learning_forecasting_suite_f184092168',
#    'exists_locally': True},
#   'forecasting_model_comparison': {'kind': 'aggregate_predictions',
#    'path': 'benchmark/results/kernel_learning/m4_full',
#    'task_type': 'forecasting',
#    'source_label': 'industrial_kernel_learning_m4_monthly_full_m100_predictions',
#    'dataset_name': 'm4_monthly_kernel_learning',
#    'series_id': 'M10781',
#    'history_length': 36,
#    'absolute_path': 'D:\\data_old\\WORK\\Repo\\Industiral\\IndustrialTS\\benchmark\\results\\kernel_learning\\m4_full',
#    'exists_locally': True}}}

# %%
{
    'current_models': [model.display_name for model in build_current_model_specs(TASK_TYPE)],
    'kernel_learning_reference_models': [model.display_name for model in build_kernel_learning_reference_model_specs(TASK_TYPE)],
}
# Out:
# {'current_models': ['NaiveLastValue',
#   'LaggedRidgeForecaster',
#   'KernelEnsembleForecaster_identity_shapelet',
#   'KernelEnsembleForecaster_embedding_nystrom_okhs'],
#  'kernel_learning_reference_models': ['NaiveLastValue',
#   'LaggedRidgeForecaster',
#   'KernelEnsembleForecaster_identity_shapelet',
#   'KernelEnsembleForecaster_embedding_nystrom_okhs']}

# %%
metric_manifest = render_analysis_notebook_pack(ANALYSIS_NAME)
[(record.kind, record.format, record.path) for record in metric_manifest]
# Out:
# [('table',
#   'csv',
#   'D:\\data_old\\WORK\\Repo\\Industiral\\IndustrialTS\\examples\\artifacts\\cloud_bundle\\benchmark_showcase\\analysis_of_results\\m4_analysis\\tables\\normalized_results.csv'),
#  ('summary',
#   'md',
#   'D:\\data_old\\WORK\\Repo\\Industiral\\IndustrialTS\\examples\\artifacts\\cloud_bundle\\benchmark_showcase\\analysis_of_results\\m4_analysis\\tables\\normalized_results.md'),
#  ('table',
#   'csv',
#   'D:\\data_old\\WORK\\Repo\\Industiral\\IndustrialTS\\examples\\artifacts\\cloud_bundle\\benchmark_showcase\\analysis_of_results\\m4_analysis\\tables\\coverage.csv'),
#  ('summary',
#   'md',
#   'D:\\data_old\\WORK\\Repo\\Industiral\\IndustrialTS\\examples\\artifacts\\cloud_bundle\\benchmark_showcase\\analysis_of_results\\m4_analysis\\tables\\coverage.md'),
#  ('table',
#   'csv',
#   'D:\\data_old\\WORK\\Repo\\Industiral\\IndustrialTS\\examples\\artifacts\\cloud_bundle\\benchmark_showcase\\analysis_of_results\\m4_analysis\\tables\\best_per_dataset.csv'),
#  ('summary',
#   'md',
#   'D:\\data_old\\WORK\\Repo\\Industiral\\IndustrialTS\\examples\\artifacts\\cloud_bundle\\benchmark_showcase\\analysis_of_results\\m4_analysis\\tables\\best_per_dataset.md'),
#  ('table',
#   'csv',
#   'D:\\data_old\\WORK\\Repo\\Industiral\\IndustrialTS\\examples\\artifacts\\cloud_bundle\\benchmark_showcase\\analysis_of_results\\m4_analysis\\tables\\mean_rank.csv'),
#  ('summary',
#   'md',
#   'D:\\data_old\\WORK\\Repo\\Industiral\\IndustrialTS\\examples\\artifacts\\cloud_bundle\\benchmark_showcase\\analysis_of_results\\m4_analysis\\tables\\mean_rank.md'),
#  ('table',
#   'csv',
#   'D:\\data_old\\WORK\\Repo\\Industiral\\IndustrialTS\\examples\\artifacts\\cloud_bundle\\benchmark_showcase\\analysis_of_results\\m4_analysis\\tables\\topk_summary.csv'),
#  ('summary',
#   'md',
#   'D:\\data_old\\WORK\\Repo\\Industiral\\IndustrialTS\\examples\\artifacts\\cloud_bundle\\benchmark_showcase\\analysis_of_results\\m4_analysis\\tables\\topk_summary.md'),
#  ('table',
#   'csv',
#   'D:\\data_old\\WORK\\Repo\\Industiral\\IndustrialTS\\examples\\artifacts\\cloud_bundle\\benchmark_showcase\\analysis_of_results\\m4_analysis\\tables\\dataset_delta.csv'),
#  ('summary',
#   'md',
#   'D:\\data_old\\WORK\\Repo\\Industiral\\IndustrialTS\\examples\\artifacts\\cloud_bundle\\benchmark_showcase\\analysis_of_results\\m4_analysis\\tables\\dataset_delta.md'),
#  ('table',
#   'csv',
#   'D:\\data_old\\WORK\\Repo\\Industiral\\IndustrialTS\\examples\\artifacts\\cloud_bundle\\benchmark_showcase\\analysis_of_results\\m4_analysis\\tables\\best_target_delta.csv'),
#  ('summary',
#   'md',
#   'D:\\data_old\\WORK\\Repo\\Industiral\\IndustrialTS\\examples\\artifacts\\cloud_bundle\\benchmark_showcase\\analysis_of_results\\m4_analysis\\tables\\best_target_delta.md'),
#  ('table',
#   'csv',
#   'D:\\data_old\\WORK\\Repo\\Industiral\\IndustrialTS\\examples\\artifacts\\cloud_bundle\\benchmark_showcase\\analysis_of_results\\m4_analysis\\tables\\dataset_difficulty.csv'),
#  ('summary',
#   'md',
#   'D:\\data_old\\WORK\\Repo\\Industiral\\IndustrialTS\\examples\\artifacts\\cloud_bundle\\benchmark_showcase\\analysis_of_results\\m4_analysis\\tables\\dataset_difficulty.md'),
#  ('table',
#   'csv',
#   'D:\\data_old\\WORK\\Repo\\Industiral\\IndustrialTS\\examples\\artifacts\\cloud_bundle\\benchmark_showcase\\analysis_of_results\\m4_analysis\\tables\\model_diagnostics.csv'),
#  ('summary',
#   'md',
#   'D:\\data_old\\WORK\\Repo\\Industiral\\IndustrialTS\\examples\\artifacts\\cloud_bundle\\benchmark_showcase\\analysis_of_results\\m4_analysis\\tables\\model_diagnostics.md'),
#  ('table',
#   'csv',
#   'D:\\data_old\\WORK\\Repo\\Industiral\\IndustrialTS\\examples\\artifacts\\cloud_bundle\\benchmark_showcase\\analysis_of_results\\m4_analysis\\tables\\generator_usage.csv'),
#  ('summary',
#   'md',
#   'D:\\data_old\\WORK\\Repo\\Industiral\\IndustrialTS\\examples\\artifacts\\cloud_bundle\\benchmark_showcase\\analysis_of_results\\m4_analysis\\tables\\generator_usage.md'),
#  ('table',
#   'csv',
#   'D:\\data_old\\WORK\\Repo\\Industiral\\IndustrialTS\\examples\\artifacts\\cloud_bundle\\benchmark_showcase\\analysis_of_results\\m4_analysis\\tables\\parameter_metric_drift.csv'),
#  ('summary',
#   'md',
#   'D:\\data_old\\WORK\\Repo\\Industiral\\IndustrialTS\\examples\\artifacts\\cloud_bundle\\benchmark_showcase\\analysis_of_results\\m4_analysis\\tables\\parameter_metric_drift.md'),
#  ('table',
#   'csv',
#   'D:\\data_old\\WORK\\Repo\\Industiral\\IndustrialTS\\examples\\artifacts\\cloud_bundle\\benchmark_showcase\\analysis_of_results\\m4_analysis\\tables\\source_metadata.csv'),
#  ('summary',
#   'md',
#   'D:\\data_old\\WORK\\Repo\\Industiral\\IndustrialTS\\examples\\artifacts\\cloud_bundle\\benchmark_showcase\\analysis_of_results\\m4_analysis\\tables\\source_metadata.md'),
#  ('summary',
#   'md',
#   'D:\\data_old\\WORK\\Repo\\Industiral\\IndustrialTS\\examples\\artifacts\\cloud_bundle\\benchmark_showcase\\analysis_of_results\\m4_analysis\\summary.md'),
#  ('table',
#   'csv',
#   'D:\\data_old\\WORK\\Repo\\Industiral\\IndustrialTS\\examples\\artifacts\\cloud_bundle\\benchmark_showcase\\analysis_of_results\\m4_analysis\\tables\\model_aliases.csv'),
#  ('summary',
#   'md',
#   'D:\\data_old\\WORK\\Repo\\Industiral\\IndustrialTS\\examples\\artifacts\\cloud_bundle\\benchmark_showcase\\analysis_of_results\\m4_analysis\\tables\\model_aliases.md'),
#  ('plot',
#   'png',
#   'D:\\data_old\\WORK\\Repo\\Industiral\\IndustrialTS\\examples\\artifacts\\cloud_bundle\\benchmark_showcase\\analysis_of_results\\m4_analysis\\plots\\mean_metric_by_model.png'),
#  ('plot',
#   'png',
#   'D:\\data_old\\WORK\\Repo\\Industiral\\IndustrialTS\\examples\\artifacts\\cloud_bundle\\benchmark_showcase\\analysis_of_results\\m4_analysis\\plots\\mean_rank_by_model.png'),
#  ('plot',
#   'png',
#   'D:\\data_old\\WORK\\Repo\\Industiral\\IndustrialTS\\examples\\artifacts\\cloud_bundle\\benchmark_showcase\\analysis_of_results\\m4_analysis\\plots\\topk_wins_by_model.png'),
#  ('plot',
#   'png',
#   'D:\\data_old\\WORK\\Repo\\Industiral\\IndustrialTS\\examples\\artifacts\\cloud_bundle\\benchmark_showcase\\analysis_of_results\\m4_analysis\\plots\\target_delta_by_dataset.png')]

# %%
forecast_manifest = render_forecasting_model_comparison_pack(artifact_name=ANALYSIS_NAME + '_forecast_models')
[(record.kind, record.format, record.path) for record in forecast_manifest]
# Out:
# [('table',
#   'csv',
#   'D:\\data_old\\WORK\\Repo\\Industiral\\IndustrialTS\\examples\\artifacts\\cloud_bundle\\benchmark_showcase\\analysis_of_results\\m4_analysis_forecast_models\\tables\\forecast_comparison.csv'),
#  ('summary',
#   'md',
#   'D:\\data_old\\WORK\\Repo\\Industiral\\IndustrialTS\\examples\\artifacts\\cloud_bundle\\benchmark_showcase\\analysis_of_results\\m4_analysis_forecast_models\\tables\\forecast_comparison.md'),
#  ('table',
#   'csv',
#   'D:\\data_old\\WORK\\Repo\\Industiral\\IndustrialTS\\examples\\artifacts\\cloud_bundle\\benchmark_showcase\\analysis_of_results\\m4_analysis_forecast_models\\tables\\forecast_metrics.csv'),
#  ('summary',
#   'md',
#   'D:\\data_old\\WORK\\Repo\\Industiral\\IndustrialTS\\examples\\artifacts\\cloud_bundle\\benchmark_showcase\\analysis_of_results\\m4_analysis_forecast_models\\tables\\forecast_metrics.md'),
#  ('metadata',
#   'json',
#   'D:\\data_old\\WORK\\Repo\\Industiral\\IndustrialTS\\examples\\artifacts\\cloud_bundle\\benchmark_showcase\\analysis_of_results\\m4_analysis_forecast_models\\source_metadata.json'),
#  ('summary',
#   'md',
#   'D:\\data_old\\WORK\\Repo\\Industiral\\IndustrialTS\\examples\\artifacts\\cloud_bundle\\benchmark_showcase\\analysis_of_results\\m4_analysis_forecast_models\\summary.md'),
#  ('plot',
#   'png',
#   'D:\\data_old\\WORK\\Repo\\Industiral\\IndustrialTS\\examples\\artifacts\\cloud_bundle\\benchmark_showcase\\analysis_of_results\\m4_analysis_forecast_models\\plots\\multi_model_forecast.png')]
