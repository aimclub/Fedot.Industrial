# %% [markdown]
# # Evolutionary Pipeline Population
#
# Thin notebook entrypoint backed by `benchmark.industrial` evolution analysis utilities.

# %%
from benchmark import industrial as industrial_benchmark
from examples.real_world_examples.benchmark_example.analysis_of_results.current_api import external_source_manifest, preflight_summary, render_pipeline_population_pack

preflight_summary()
# Out:
# {'version': 'industrial_real_world_analysis@1',
#  'available_analyses': ('analysis_multi_clf',
#   'analysis_regr',
#   'analysis_uni_clf',
#   'm4_analysis',
#   'pdl_uni_benchmark'),
#  'feature_generators': ('quantile_extractor_torch',
#   'wavelet_extractor',
#   'fourier_extractor',
#   'eigen_extractor',
#   'minirocket_extractor'),
#  'analysis_sources': {'analysis_uni_clf': ('benchmark/results/time_series_uni_clf_comparasion_2024.csv',
#    'benchmark/results/v2_kernel_learning/ucr_suite_020626'),
#   'analysis_multi_clf': ('benchmark/results/time_series_multI_clf_comparasion_241223.csv',),
#   'analysis_regr': ('benchmark/results/time_series_multi_reg_comparasion_2024.csv',
#    'benchmark/results/v2_kernel_learning/tser_suite_140526'),
#   'm4_analysis': ('benchmark/results/v2_kernel_learning/forecasting_suite_140526',),
#   'pdl_uni_benchmark': ('benchmark/results/v2_kernel_learning/ucr_suite_020626',
#    'benchmark/results/kernel_learning/pdl_ucr_full')},
# ...

# %%
external_source_manifest()
# Out:
# {'composition_results': {'path': 'examples/utils/data/benchmark_history/real_world_archive/composition_results',
#   'task_type': 'mixed',
#   'source_label': 'fedot_industrial_evolution_history',
#   'dvc_key': 'real_world_archive_composition_results',
#   'absolute_path': 'D:\\data_old\\WORK\\Repo\\Industiral\\IndustrialTS\\examples\\utils\\data\\benchmark_history\\real_world_archive\\composition_results',
#   'exists_locally': True},
#  'm3_m4_data': {'path': 'examples/utils/data/benchmark_history/real_world_archive/data',
#   'task_type': 'forecasting',
#   'source_label': 'local_m3_m4_archive_data',
#   'dvc_key': 'real_world_archive_m3_m4_data',
#   'absolute_path': 'D:\\data_old\\WORK\\Repo\\Industiral\\IndustrialTS\\examples\\utils\\data\\benchmark_history\\real_world_archive\\data',
#   'exists_locally': True},
#  'forecasting_progress_items': {'path': 'benchmark/results/v2_kernel_learning/forecasting_suite_140526/kernel_learning_forecasting_suite_f184092168',
# ...

# %%
manifest = render_pipeline_population_pack()
[(record.kind, record.format, record.path) for record in manifest]
# Out:
# [('table',
#   'csv',
#   'D:\\data_old\\WORK\\Repo\\Industiral\\IndustrialTS\\examples\\artifacts\\cloud_bundle\\benchmark_showcase\\analysis_of_results\\pipeline_population\\tables\\coverage.csv'),
#  ('summary',
#   'md',
#   'D:\\data_old\\WORK\\Repo\\Industiral\\IndustrialTS\\examples\\artifacts\\cloud_bundle\\benchmark_showcase\\analysis_of_results\\pipeline_population\\tables\\coverage.md'),
#  ('table',
#   'csv',
#   'D:\\data_old\\WORK\\Repo\\Industiral\\IndustrialTS\\examples\\artifacts\\cloud_bundle\\benchmark_showcase\\analysis_of_results\\pipeline_population\\tables\\composition_history.csv'),
#  ('summary',
#   'md',
#   'D:\\data_old\\WORK\\Repo\\Industiral\\IndustrialTS\\examples\\artifacts\\cloud_bundle\\benchmark_showcase\\analysis_of_results\\pipeline_population\\tables\\composition_history.md'),
#  ('table',
#   'csv',
# ...
