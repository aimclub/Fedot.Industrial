# %% [markdown]
# # Evolutionary Pipeline Population
#
# Thin notebook entrypoint backed by `benchmark.industrial` evolution analysis utilities.

# %%
from benchmark import industrial as industrial_benchmark
from examples.real_world_examples.benchmark_example.analysis_of_results.current_api import external_source_manifest, preflight_summary, render_pipeline_population_pack

preflight_summary()
# Out:
# {'version': 'industrial_real_world_analysis@1',
#  'available_analyses': ('analysis_multi_clf',
#   'analysis_regr',
#   'analysis_uni_clf',
#   'm4_analysis',
#   'pdl_uni_benchmark'),
#  'feature_generators': ('quantile_extractor_torch',
#   'wavelet_extractor',
#   'fourier_extractor',
#   'eigen_extractor',
#   'minirocket_extractor'),
#  'external_sources': {'composition_results': {'path': 'examples/utils/data/benchmark_history/real_world_archive/composition_results',
#    'task_type': 'mixed',
#    'source_label': 'fedot_industrial_evolution_history',
#    'dvc_key': 'real_world_archive_composition_results',
#    'absolute_path': 'D:\\data_old\\WORK\\Repo\\Industiral\\IndustrialTS\\examples\\real_world_examples\\benchmark_example\\archive\\composition_results',
#    'exists_locally': True},
#   'm3_m4_data': {'path': 'examples/utils/data/benchmark_history/real_world_archive/data',
#    'task_type': 'forecasting',
#    'source_label': 'local_m3_m4_archive_data',
#    'dvc_key': 'real_world_archive_m3_m4_data',
#    'absolute_path': 'D:\\data_old\\WORK\\Repo\\Industiral\\IndustrialTS\\examples\\real_world_examples\\benchmark_example\\archive\\data',
#    'exists_locally': True}}}

# %%
external_source_manifest()
# Out:
# {'composition_results': {'path': 'examples/utils/data/benchmark_history/real_world_archive/composition_results',
#   'task_type': 'mixed',
#   'source_label': 'fedot_industrial_evolution_history',
#   'dvc_key': 'real_world_archive_composition_results',
#   'absolute_path': 'D:\\data_old\\WORK\\Repo\\Industiral\\IndustrialTS\\examples\\real_world_examples\\benchmark_example\\archive\\composition_results',
#   'exists_locally': True},
#  'm3_m4_data': {'path': 'examples/utils/data/benchmark_history/real_world_archive/data',
#   'task_type': 'forecasting',
#   'source_label': 'local_m3_m4_archive_data',
#   'dvc_key': 'real_world_archive_m3_m4_data',
#   'absolute_path': 'D:\\data_old\\WORK\\Repo\\Industiral\\IndustrialTS\\examples\\real_world_examples\\benchmark_example\\archive\\data',
#   'exists_locally': True}}

# %%
manifest = render_pipeline_population_pack()
[(record.kind, record.format, record.path) for record in manifest]
# Out:
# [('table',
#   'csv',
#   'D:\\data_old\\WORK\\Repo\\Industiral\\IndustrialTS\\examples\\real_world_examples\\benchmark_example\\analysis_of_results\\vis_artifacts\\pipeline_population\\tables\\composition_history.csv'),
#  ('summary',
#   'md',
#   'D:\\data_old\\WORK\\Repo\\Industiral\\IndustrialTS\\examples\\real_world_examples\\benchmark_example\\analysis_of_results\\vis_artifacts\\pipeline_population\\tables\\composition_history.md'),
#  ('table',
#   'csv',
#   'D:\\data_old\\WORK\\Repo\\Industiral\\IndustrialTS\\examples\\real_world_examples\\benchmark_example\\analysis_of_results\\vis_artifacts\\pipeline_population\\tables\\evolution_dynamics.csv'),
#  ('summary',
#   'md',
#   'D:\\data_old\\WORK\\Repo\\Industiral\\IndustrialTS\\examples\\real_world_examples\\benchmark_example\\analysis_of_results\\vis_artifacts\\pipeline_population\\tables\\evolution_dynamics.md'),
#  ('table',
#   'csv',
#   'D:\\data_old\\WORK\\Repo\\Industiral\\IndustrialTS\\examples\\real_world_examples\\benchmark_example\\analysis_of_results\\vis_artifacts\\pipeline_population\\tables\\pipeline_complexity.csv'),
#  ('summary',
#   'md',
#   'D:\\data_old\\WORK\\Repo\\Industiral\\IndustrialTS\\examples\\real_world_examples\\benchmark_example\\analysis_of_results\\vis_artifacts\\pipeline_population\\tables\\pipeline_complexity.md'),
#  ('table',
#   'csv',
#   'D:\\data_old\\WORK\\Repo\\Industiral\\IndustrialTS\\examples\\real_world_examples\\benchmark_example\\analysis_of_results\\vis_artifacts\\pipeline_population\\tables\\notable_pipelines.csv'),
#  ('summary',
#   'md',
#   'D:\\data_old\\WORK\\Repo\\Industiral\\IndustrialTS\\examples\\real_world_examples\\benchmark_example\\analysis_of_results\\vis_artifacts\\pipeline_population\\tables\\notable_pipelines.md'),
#  ('summary',
#   'md',
#   'D:\\data_old\\WORK\\Repo\\Industiral\\IndustrialTS\\examples\\real_world_examples\\benchmark_example\\analysis_of_results\\vis_artifacts\\pipeline_population\\summary.md'),
#  ('plot',
#   'png',
#   'D:\\data_old\\WORK\\Repo\\Industiral\\IndustrialTS\\examples\\real_world_examples\\benchmark_example\\analysis_of_results\\vis_artifacts\\pipeline_population\\plots\\best_fitness_by_generation.png'),
#  ('plot',
#   'png',
#   'D:\\data_old\\WORK\\Repo\\Industiral\\IndustrialTS\\examples\\real_world_examples\\benchmark_example\\analysis_of_results\\vis_artifacts\\pipeline_population\\plots\\complexity_vs_fitness.png')]
